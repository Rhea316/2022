# %%
"Runoob example....wow!!!".rjust(50, '*')
# Out:
# '**************************Runoob example....wow!!!'

# %%
print("Runoob example....wow!!!")
# Out:
# Ru\noob example....wow!!!

# %%
import os
os.chdir(r"E:\琅琊经侦传销 6月9日")


for a in os.walk(os.getcwd()):
    print(a)
a
# Out:
# ('E:\\琅琊经侦传销 6月9日', [], ['user.xlsx', 'user_0.xlsx', 'user_1.xlsx', 'user_10.xlsx', 'user_11.xlsx', 'user_12.xlsx', 'user_13.xlsx', 'user_14.xlsx', 'user_2.xlsx', 'user_3.xlsx', 'user_4.xlsx', 'user_5.xlsx', 'user_6.xlsx', 'user_7.xlsx', 'user_8.xlsx', 'user_9.xlsx'])
# ('E:\\琅琊经侦传销 6月9日',
#  [],
#  ['user.xlsx',
#   'user_0.xlsx',
#   'user_1.xlsx',
#   'user_10.xlsx',
#   'user_11.xlsx',
#   'user_12.xlsx',
#   'user_13.xlsx',
#   'user_14.xlsx',
#   'user_2.xlsx',
#   'user_3.xlsx',
#   'user_4.xlsx',
#   'user_5.xlsx',
#   'user_6.xlsx',
#   'user_7.xlsx',
#   'user_8.xlsx',
#   'user_9.xlsx'])

# %%
import pandas as pd
pd.DataFrame(file_list).to_excel(r"E:\7.3徐州网赌\20200701宗整理数据.xlsx")

# %% [markdown]
# 文件夹内，所有包含关键词str的文件

# %% [markdown]
# 关键词“交易明细信息”

# %% [markdown]
# 关键词“账户信息”

# %% [markdown]
# 关键词“”,即全部

# %%
import os
str1 = '$'
file_list = []

os.chdir(r"E:\7.3徐州网赌\20200701宗整理数据")
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if str1 not in file:
#             file_list.append(os.path.join(path_name, file))
            file_list.append(os.path.join(file))
file_list
# Out:
# ['(339)中国农业银行6213361929900647773.xls',
#  '(339)中国农业银行6228270292000372372.xls',
#  '(339)中国农业银行6228410634533805470.xls',
#  '(339)中国农业银行6228430339429784773.xls',
#  '(339)中国农业银行6228450298045100670.xls',
#  '(339)中国农业银行6228451010022418911.xls',
#  '(339)中国农业银行6228453378006365574.xls',
#  '(339)中国农业银行6228480018414257974.xls',
#  '(339)中国农业银行6228480018703391773.xls',
#  '(339)中国农业银行6228480018786806077.xls',
#  '(339)中国农业银行6228480038675802672.xls',
#  '(339)中国农业银行6228480048249739375.xls',
#  '(339)中国农业银行6228480178361302478.xls',
#  '(339)中国农业银行6228480180628258113.xls',
#  '(339)中国农业银行6228480198443151370.xls',
#  '(339)中国农业银行6228480240281687816.xls',
#  '(339)中国农业银行6228480240523296210.xls',
#  '(339)中国农业银行6228480246012537360.xls',
#  '(339)中国农业银行6228480246032404567.xls',
#  '(339)中国农业银行6228480246091490069.xls',
#  '(339)中国农业银行6228480248023412872.xls',
#  '(339)中国农业银行6228480248153430074.xls',
#  '(339)中国农业银行6228480286141510268.xls',
#  '(339)中国农业银行6228480290740880916.xls',
#  '(339)中国农业银行6228480290859713817.xls',
#  '(339)中国农业银行6228480291880321414.xls',
#  '(339)中国农业银行6228480292680285916.xls',
#  '(339)中国农业银行6228480292680394510.xls',
#  '(339)中国农业银行6228480296667463362.xls',
#  '万鑫6217001930026509415.xls',
#  '上海浦东发展银行股份有限公司交易明细信息 (6.19).csv',
#  '不祥.xls',
#  '不祥4100625959000048.xls',
#  '不祥4100626550011715.xls',
#  '不祥4100626551911715.xls',
#  '不祥4682037808850415.xls',
#  '不祥4682037816850415.xls',
#  '不祥6214832150579436.xls',
#  '不祥6214833793741458.xls',
#  '不祥6214835795302809.xls',
#  '不祥6214837831022268.xls',
#  '不祥6214838642690186.xls',
#  '不祥6214855956172866.xls',
#  '不祥6225887811277983.xls',
#  '不祥6225887834485233.xls',
#  '不祥6226096554914963.xls',
#  '东广军6222080908000265661工商银行.xls',
#  '严鑫（中国农业银行）6230520460174815179.xls',
#  '严鑫（浙江民泰银行6217261028013451637）.xls',
#  '中信银行交易明细信息 (6.19).csv',
#  '中国光大银行股份有限公司交易明细信息 (6.19).csv',
#  '中国农业银行6228480068346346478.xls',
#  '中国工商银行交易明细信息 (6.19).csv',
#  '中国建设银行交易明细信息 (6.19).csv',
#  '中国民生银行股份有限公司交易明细信息 (6.19).csv',
#  '中国邮政储蓄银行有限责任公司交易明细信息 (6.19).csv',
#  '中国银行交易明细信息 (6.19).csv',
#  '中长胜基金管理有限公司4000010309200339856.xls',
#  '临沂市鸿途物流服务中心（中国光大银行）53190188000015803.xls',
#  '于福6217000400005789199.xls',
#  '亚太联盟（厦门）影视传媒有限公司4100028509200111308.xls',
#  '交通银行股份有限公司交易明细信息 (6.19).csv',
#  '人员联系方式信息（6.19）.csv',
#  '任文浩6222020302079613055.xls',
#  '伍伟（中国邮政储蓄）6217997010016305185.xls',
#  '伍伟（邮政储蓄银行6217997010016305185）.et',
#  '伍伟（邮政储蓄银行6217997010016305185）.xls',
#  '伍伟（邮政储蓄银行）6217997010016305185.xls',
#  '何东舟（上海浦东发展银行）6217920118949309.xls',
#  '何卓勒6214537553295973.xls',
#  '何园（农业银行6213360807347762762）.xls',
#  '何擎华（桂林银行6215620002001329832）.xls',
#  '何明安（上海浦东发展银行6217923300287157 ）.et',
#  '何焕霞6217907000030356347.xls',
#  '何甜（中国邮政储蓄）6221807900005117934.xls',
#  '余旭游6228480380189321215.xls',
#  '余飞云6228450068042818479.xls',
#  '侯生军6227002220408696909.xls',
#  '侯迎光6214857550342937招商银行.xls',
#  '侯远白（中国农业银行）6230520680057227677.xls',
#  '全宏伟6227000012710331438.xls',
#  '兰军林6228480068821985873.xls',
#  '兰军林（农行6228480068821985873）.xls',
#  '兰林军（中国农业银行）6228480068821985873.xls',
#  '兴业银行22908133021016608（查不到账户信息）.xls',
#  '兴业银行6229220392883092（查不到账户信息）.xls',
#  '兴业银行股份有限公司交易明细信息 (6.19).csv',
#  '冯亚娟6228480208004977673.xls',
#  '冯灿6217933775302142.xls',
#  '刘丽红（建行6217001830043523177）.xls',
#  '刘云鸿6217003930001741874.xls',
#  '刘伟1001810044484698_C100CNY.xls',
#  '刘冉冉6228430389683234577.xls',
#  '刘冬6214833795122905.xls',
#  '刘冰冰6214881838856666.xls',
#  '刘冰冰6228480688849016870.xls',
#  '刘冰冰6230361107007145868.xls',
#  '刘利杰6224490108953597.xls',
#  '刘合622439380005818156.xls',
#  '刘婉娣6217001830013754364.xls',
#  '刘安琦（平安银行）6230582000075673064.xls',
#  '刘家杭6217000260001903669.xls',
#  '刘射仔6222759502620727.xls',
#  '刘建军6217002210009167427.xls',
#  '刘明林6222034000029622200.xls',
#  '刘晓6214851256713491.xls',
#  '刘晓6216606300004648463.xls',
#  '刘晓6217001720006513556.xls',
#  '刘晓6217788368207098875.xls',
#  '刘杰6212264402095515312.xls',
#  '刘杰（中国农业银行）6230520460176341778.xls',
#  '刘杰（农业银行6228480414583629715）.xls',
#  '刘松（招商银行）6214837981841129.xls',
#  '刘洋6222759502461551.xls',
#  '刘涛（农行6230523150021739378）.xls',
#  '刘燕燕（农业银行）6228480068346346478.xls',
#  '刘爽6217261028013084727.xls',
#  '刘爽6230520460191278971.xls',
#  '刘玲6217001720014253450.xls',
#  '刘礼灿6222623710001004758.xls',
#  '刘祥阳6222624050001382873.xls',
#  '刘茹莲6215591804000994044工商银行.xls',
#  '刘衰珠6228480389461913771.xls',
#  '刘路路（建行6217001250013451368）.et',
#  '刘路路（招商银行）6214852110881771.xls',
#  '刘鑫6217002920003523868.xls',
#  '刘阳（建行6217003800030672970）.xls',
#  '刘阳（浙江民泰银行6270430501000272058）.xls',
#  '刘阳（邮政储蓄银行6217996510031881814）.et',
#  '刘雄勇6216912304689667.xls',
#  '刘雄勇6217001830040035647.xls',
#  '刘雄勇6230580000274641708.xls',
#  '刘雅萍6228450128007719474.xls',
#  '刘静雅6229226756659101.xls',
#  '刘静雅6230580000159277248.xls',
#  '包娈英6217001740005760297.xls',
#  '北京中关村银行1005890001500022988.xls',
#  '匡树林6217007200062829794.xls',
#  '卓孝唯6212261407006611459.xls',
#  '卓孝唯6227001892690254109.xls',
#  '卓维康6230520060076429176.xls',
#  '南安霞美坤灵灯饰商行1408868209000034475.xls',
#  '卜建伟6228435019002122618.xls',
#  '卢企华6217000310004140007.xls',
#  '卢凤珍（工商银行6222022010039884934）.xls',
#  '卢梓民（中国银行6217907000022691883）.xls',
#  '卢沛全（中国银行661356491314）.xls',
#  '卢泽民6217000310004427743.xls',
#  '卢清榕6230362509027160406.xls',
#  '卢章伦6230520680053429673.xls',
#  '厦门银行股份有限公司交易明细信息（6.19）.csv',
#  '叶耀茹6230583000008785042.xls',
#  '叶艺芳6214855921978199.xls',
#  '向华印6217003760142593532.xls',
#  '向石6226192012872610.xls',
#  '向石（成都农村商业银行6230880010013211462）.xls',
#  '向艳6217710310042031.xls',
#  '向艳6226220640017900.xls',
#  '向芬芬6217710310042049.xls',
#  '吕刚锋6228480388080372179.xls',
#  '吕帅6214852126274631.xls',
#  '吴丽玉6236681830001903855.xls',
#  '吴优6217920955026153.xls',
#  '吴佩振6222620799955558888.xls',
#  '吴先瑞（上海浦东发展银行6217933351035322 ）.et',
#  '吴先瑞（建行6217001720013696675）.et',
#  '吴华凯（邮政储蓄银行6217993320019570196）.xls',
#  '吴圣梅6217001830035582520.xls',
#  '吴学勤（农业银行6228480083430225314）.xls',
#  '蔡芬芳6221840207000345885.xls',
#  '蔡芬芳6226192301293221.xls',
#  '蔡芬芳6226192380073072.xls',
#  '蔡芬芳62261923801271676.xls',
#  '蔡芬芳6226192380610634.xls',
#  '蔡芬芳6227001833660052222.xls',
#  '蔡芬芳6227001833660083888.xls',
#  '蔡银柱6228480089982290978.xls',
#  '蔺庆增6227000424220007616.xls',
#  '蔺建玲6217002250002975798.xls',
#  '薛成义6228480381251954719.xls',
#  '袁倩儿6217003110004884985.xls',
#  '袁成玉6214836550719435.xls',
#  '袁扬杨6214372600002864252.xls',
#  '袁树波（工商银行6222032010005305839）.xls',
#  '袁永欢4340612020140177.xls',
#  '袁永欢6230520680075124773.xls',
#  '袁胜平6214830203018071.xls',
#  '裘凌燕6214867837840918.xls',
#  '詹成隆6217001930014560701.xls',
#  '詹成隆6221803930000434525.xls',
#  '许伟伟（中国银行6217906300023397683）.et',
#  '许冰冰6230520680014926874.xls',
#  '许永坤6213360686019134462.xls',
#  '许永坤（中国农业银行）6213360686019134462.xls',
#  '许爱芳（中国农业银行）6228481998568847879.xls',
#  '许芳6216911507196744.xls',
#  '许飞云6232111830000891217.xls',
#  '谢利琼（农业银行6228481459871939770）.xls',
#  '谢子丰6217000010148500005.xls',
#  '谢彬娥6217856400008721509.xls',
#  '谢志伟6217231402001289944.xls',
#  '谢志伟（工商银行6217231402001289944）.xls',
#  '谢红珍6217993000212492980.xls',
#  '谭友义（中国农业银行）6228480809474199779.xls',
#  '谭友战6217002950112528300.xls',
#  '贺阿龙（上海浦东发展银行6217933375183231）.xls',
#  '贺阿龙（建行6217001720000377784）.xls',
#  '赖政龙6222623110005505753.xls',
#  '赖明超6214991936715555.xls',
#  '赖明超6226220639616704.xls',
#  '赖绿6222620790001353408.xls',
#  '赖绿6222620796531888888.xls',
#  '赵书北6217000310004271240.xls',
#  '赵伟（工商银行6212261905005722839）.xls',
#  ...]

# %%
import os
os.chdir(r"F:\新建文件夹")

os.walk(os.getcwd())
# Out:
# <generator object walk at 0x0000018D78BBA448>

# %%
for a in os.walk(os.getcwd()):
a
# Out:
# ('F:\\新建文件夹',
#  [],
#  ['0823.xlsx',
#   '460031199510160823.xlsx',
#   'user_0.xlsx',
#   'user_1.xlsx',
#   'user_10.xlsx',
#   'user_11.xlsx',
#   'user_12.xlsx',
#   'user_13.xlsx',
#   'user_14.xlsx',
#   'user_2.xlsx',
#   'user_3.xlsx',
#   'user_4.xlsx',
#   'user_5.xlsx',
#   'user_6.xlsx',
#   'user_7.xlsx',
#   'user_8.xlsx',
#   'user_9.xlsx',
#   '合并.csv',
#   '滁州传销.csv',
#   '滁州传销.xlsx'])

# %%
# # 示例，添加path、编号，然后按照原列名去重，新表data_1

# i = 3
# df = pd.read_csv(file_list[i],encoding='gbk')
# print(file_list[i])
# print(df.shape)
# print(df.duplicated().value_counts()) # 表内重复值行数 'True 数量'
# col_list = list(df.columns)
# df['path'] = file_list[i]
# df['编号'] = df.index
# data_1 = df.drop_duplicates(subset = col_list)
# print(data_1)
# print(data_1.duplicated().value_counts())

# %% [markdown]
# 上面file_list中，xls、xlsx、csv格式文件读取

# %% [markdown]
# df_group表是path、columns两列统计表,all_data表是读取的所有文件合并

# %% [markdown]
# colunmns不同合并失败，故需要识别colunms再分组

# %%
# import pandas as pd
# all_data = pd.DataFrame()
# df_group = pd.DataFrame(columns = ['Path','Columns'])
# type1 = '.xls'
# type2 = '.csv'
# for i in range(len(file_list)):
#     print(i)
#     if type1 in file_list[i]:
#         df = pd.read_excel(file_list[i], encoding = "gbk")
#         col_name = df.columns.tolist()
#         df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name)}
        
#         print(df.shape)
#         print(df.duplicated().value_counts()) # 表内重复值行数 'True 数量'
#         df['path'] = file_list[i]
#         df['编号'] = df.index
#         data_1 = df.drop_duplicates(subset = col_name,keep = 'last')
#         all_data = all_data.append(data_1)
#     elif type2 in file_list[i]:
#         df = pd.read_csv(file_list[i], engine = "python")
#         col_name = df.columns.tolist()      
#         df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name)}
        
#         print(df.shape)
#         print(df.duplicated().value_counts()) # 表内重复值行数 'True 数量'
#         df['path'] = file_list[i]
#         df['编号'] = df.index
#         data_1 = df.drop_duplicates(subset = col_name,keep = 'last')
#         all_data = all_data.append(data_1)

# print(all_data.shape)
# Out:
# 0
# (4571, 32)
# False    4571
# dtype: int64
# 1
# (2085, 32)
# False    2085
# dtype: int64
# 2
# (253, 32)
# False    253
# dtype: int64
# 3
# (25768, 32)
# False    17414
# True      8354
# dtype: int64
# 4
# (251, 32)
# False    251
# dtype: int64
# 5
# (23, 32)
# False    23
# dtype: int64
# 6
# (609, 32)
# False    609
# dtype: int64
# 7
# (735, 32)
# False    735
# dtype: int64
# 8
# (1471, 32)
# False    1471
# dtype: int64
# 9
# (1755, 32)
# False    1755
# dtype: int64
# 10
# (136, 32)
# False    136
# dtype: int64
# 11
# (1599, 32)
# False    1599
# dtype: int64
# 12
# (8866, 32)
# False    8866
# dtype: int64
# 13
# (5126, 32)
# False    5126
# dtype: int64
# 14
# (17879, 32)
# False    17879
# dtype: int64
# 15
# (502, 32)
# False    502
# dtype: int64
# 16
# (12525, 32)
# False    12525
# dtype: int64
# 17
# (13029, 32)
# False    13029
# dtype: int64
# 18
# (1941, 32)
# False    1941
# dtype: int64
# 19
# (40976, 32)
# False    40976
# dtype: int64
# 20
# (2564, 32)
# False    2564
# dtype: int64
# 21
# (15590, 32)
# False    15590
# dtype: int64
# 22
# (14282, 32)
# False    14282
# dtype: int64
# 23
# (9229, 32)
# False    9229
# dtype: int64
# 24
# (2015, 32)
# False    2015
# dtype: int64
# 25
# (2607, 32)
# False    2607
# dtype: int64
# 26
# (2857, 32)
# False    2849
# True        8
# dtype: int64
# 27
# (6189, 32)
# False    6187
# True        2
# dtype: int64
# 28
# (404, 32)
# False    404
# dtype: int64
# 29
# (1320, 32)
# False    1320
# dtype: int64
# 30
# (3161, 32)
# False    3161
# dtype: int64
# 31
# (2709, 32)
# False    2709
# dtype: int64
# 32
# (11326, 32)
# False    11326
# dtype: int64
# 33
# (15, 32)
# False    15
# dtype: int64
# 34
# (24032, 32)
# False    17357
# True      6675
# dtype: int64
# 35
# (2865, 32)
# False    2865
# dtype: int64
# 36
# (468, 32)
# False    468
# dtype: int64
# 37
# (668, 32)
# False    668
# dtype: int64
# 38
# (6676, 32)
# False    6676
# dtype: int64
# 39
# (3491, 32)
# False    3491
# dtype: int64
# 40
# (1387, 32)
# False    1387
# dtype: int64
# 41
# (1590, 32)
# False    1590
# dtype: int64
# 42
# (10125, 32)
# False    10125
# dtype: int64
# 43
# (1000, 32)
# False    1000
# dtype: int64
# 44
# (1000, 32)
# False    1000
# dtype: int64
# 45
# (218, 32)
# False    218
# dtype: int64
# 46
# (9296, 32)
# False    9296
# dtype: int64
# 47
# (662, 32)
# False    662
# dtype: int64
# 48
# (2254, 32)
# False    2254
# dtype: int64
# 49
# (3367, 32)
# False    3367
# dtype: int64
# 50
# (5118, 32)
# False    5118
# dtype: int64
# 51
# (7611, 32)
# False    7611
# dtype: int64
# 52
# (942, 32)
# False    942
# dtype: int64
# 53
# (751, 32)
# False    751
# dtype: int64
# 54
# (1268, 32)
# False    1268
# dtype: int64
# 55
# (1702, 32)
# False    1702
# dtype: int64
# 56
# (4020, 32)
# False    4020
# dtype: int64
# 57
# (1100, 32)
# False    1100
# dtype: int64
# 58
# (930, 32)
# False    930
# dtype: int64
# 59
# (128, 32)
# False    128
# dtype: int64
# 60
# (7993, 32)
# False    7993
# dtype: int64
# 61
# (6564, 32)
# False    6564
# dtype: int64
# 62
# (22520, 32)
# False    22520
# dtype: int64
# 63
# (2564, 32)
# False    2564
# dtype: int64
# 64
# (22520, 32)
# False    22520
# dtype: int64
# 65
# (7993, 32)
# False    7993
# dtype: int64
# 66
# (2187, 32)
# False    2187
# dtype: int64
# 67
# (2406, 32)
# False    2406
# dtype: int64
# 68
# (1197, 32)
# False    1197
# dtype: int64
# 69
# (9152, 32)
# False    9152
# dtype: int64
# 70
# (23459, 32)
# False    23459
# dtype: int64
# 71
# (15026, 32)
# False    15026
# dtype: int64
# 72
# (4698, 32)
# False    4698
# dtype: int64
# 73
# (6725, 32)
# False    6725
# dtype: int64
# 74
# (278, 32)
# False    278
# dtype: int64
# 75
# (1342, 32)
# False    1342
# dtype: int64
# 76
# (1106, 32)
# False    1106
# dtype: int64
# 77
# (1218, 32)
# False    1218
# dtype: int64
# 78
# (190, 32)
# False    190
# dtype: int64
# 79
# (792, 32)
# False    792
# dtype: int64
# 80
# (210, 32)
# False    210
# dtype: int64
# 81
# (159, 32)
# False    159
# dtype: int64
# 82
# (2603, 32)
# False    2603
# dtype: int64
# 83
# (995, 32)
# False    995
# dtype: int64
# 84
# (223, 32)
# False    223
# dtype: int64
# 85
# (4996, 32)
# False    4996
# dtype: int64
# 86
# (9295, 32)
# False    9295
# dtype: int64
# 87
# (463, 32)
# False    463
# dtype: int64
# 88
# (190, 32)
# False    190
# dtype: int64
# 89
# (1958, 32)
# False    1958
# dtype: int64
# 90
# (5622, 32)
# False    5622
# dtype: int64
# 91
# (2546, 32)
# False    2546
# dtype: int64
# 92
# (1248, 32)
# False    1248
# dtype: int64
# 93
# (63, 32)
# False    63
# dtype: int64
# 94
# (153, 32)
# False    153
# dtype: int64
# 95
# (110441, 32)
# False    110437
# True          4
# dtype: int64
# 96
# (37115, 32)
# False    23192
# True     13923
# dtype: int64
# 97
# (95691, 32)
# False    95691
# dtype: int64
# 98
# (65535, 32)
# False    65534
# True         1
# dtype: int64
# 99
# (7240, 32)
# True     3620
# False    3620
# dtype: int64
# 100
# (6825, 32)
# False    6825
# dtype: int64
# 101
# (450, 32)
# False    450
# dtype: int64
# 102
# (103, 32)
# False    103
# dtype: int64
# 103
# (13390, 32)
# False    13390
# dtype: int64
# 104
# (546, 32)
# False    546
# dtype: int64
# 105
# (2264, 32)
# False    2264
# dtype: int64
# 106
# (2615, 32)
# False    2615
# dtype: int64
# 107
# (2581, 32)
# False    2581
# dtype: int64
# 108
# (4079, 32)
# False    4079
# dtype: int64
# 109
# (2035, 32)
# False    2035
# dtype: int64
# 110
# (85, 32)
# False    85
# dtype: int64
# 111
# (2604, 32)
# False    2604
# dtype: int64
# 112
# (996, 32)
# False    996
# dtype: int64
# 113
# (763, 32)
# False    763
# dtype: int64
# 114
# (2657, 32)
# False    2657
# dtype: int64
# 115
# (595, 32)
# False    595
# dtype: int64
# 116
# (2160, 32)
# False    2160
# dtype: int64
# 117
# (7191, 32)
# False    7191
# dtype: int64
# 118
# (2479, 32)
# False    2479
# dtype: int64
# 119
# (2479, 32)
# False    2479
# dtype: int64
# 120
# (1000, 32)
# False    1000
# dtype: int64
# 121
# (1061, 32)
# False    1061
# dtype: int64
# 122
# (1701, 32)
# False    1701
# dtype: int64
# 123
# (4100, 32)
# False    4100
# dtype: int64
# 124
# (11753, 32)
# False    11753
# dtype: int64
# 125
# (148074, 32)
# False    148074
# dtype: int64
# 126
# (2901, 32)
# False    2901
# dtype: int64
# 127
# (1094, 32)
# False    1094
# dtype: int64
# 128
# (797, 32)
# False    797
# dtype: int64
# 129
# (1349, 32)
# False    1349
# dtype: int64
# 130
# (6000, 32)
# False    5994
# True        6
# dtype: int64
# 131
# (3412, 32)
# False    3412
# dtype: int64
# 132
# (12323, 32)
# False    12323
# dtype: int64
# 133
# (326, 32)
# False    326
# dtype: int64
# 134
# (10, 32)
# False    10
# dtype: int64
# 135
# (2623, 32)
# False    2623
# dtype: int64
# 136
# (4537, 32)
# False    4537
# dtype: int64
# 137
# (1590, 32)
# False    1590
# dtype: int64
# 138
# (372, 32)
# False    372
# dtype: int64
# 139
# (211, 32)
# False    211
# dtype: int64
# 140
# (148, 32)
# False    148
# dtype: int64
# 141
# (724, 32)
# False    724
# dtype: int64
# 142
# (37, 32)
# False    37
# dtype: int64
# 143
# (1849, 32)
# False    1849
# dtype: int64
# 144
# (1980, 32)
# False    1980
# dtype: int64
# 145
# (216, 32)
# False    216
# dtype: int64
# 146
# (1377, 32)
# False    1377
# dtype: int64
# 147
# (3782, 32)
# False    3782
# dtype: int64
# 148
# (175, 32)
# False    175
# dtype: int64
# 149
# (4243, 32)
# False    4243
# dtype: int64
# 150
# (358, 32)
# False    358
# dtype: int64
# 151
# (5403, 32)
# False    5403
# dtype: int64
# 152
# (2851, 32)
# False    2851
# dtype: int64
# 153
# (30692, 32)
# False    25078
# True      5614
# dtype: int64
# 154
# (18919, 32)
# False    18919
# dtype: int64
# 155
# (2232, 32)
# False    2232
# dtype: int64
# 156
# (144, 32)
# False    144
# dtype: int64
# 157
# (38721, 32)
# False    37152
# True      1569
# dtype: int64
# 158
# (1289, 32)
# False    1289
# dtype: int64
# 159
# (42690, 32)
# False    41477
# True      1213
# dtype: int64
# 160
# (200000, 32)
# False    199999
# True          1
# dtype: int64
# 161
# (23263, 32)
# False    23263
# dtype: int64
# 162
# (11503, 32)
# False    11503
# dtype: int64
# 163
# (2728, 32)
# False    1642
# True     1086
# dtype: int64
# 164
# (3840, 32)
# False    3840
# dtype: int64
# 165
# (2296, 32)
# False    2296
# dtype: int64
# 166
# (1000, 32)
# False    1000
# dtype: int64
# 167
# (3006, 32)
# False    3006
# dtype: int64
# 168
# (1781, 32)
# False    1781
# dtype: int64
# 169
# (421, 32)
# False    421
# dtype: int64
# 170
# (1256, 32)
# False    1256
# dtype: int64
# 171
# (33, 32)
# False    33
# dtype: int64
# 172
# (521, 32)
# False    521
# dtype: int64
# 173
# (123, 32)
# False    123
# dtype: int64
# 174
# (214, 32)
# False    214
# dtype: int64
# 175
# (197, 32)
# False    197
# dtype: int64
# 176
# (89, 32)
# False    89
# dtype: int64
# 177
# (2427, 32)
# False    2427
# dtype: int64
# 178
# (62, 32)
# False    62
# dtype: int64
# 179
# (219, 32)
# False    219
# dtype: int64
# 180
# (34551, 32)
# False    34551
# dtype: int64
# 181
# (5979, 32)
# False    5979
# dtype: int64
# 182
# (23934, 32)
# False    23934
# dtype: int64
# 183
# (816, 32)
# False    816
# dtype: int64
# 184
# (1, 32)
# False    1
# dtype: int64
# 185
# (6206, 32)
# False    6187
# True       19
# dtype: int64
# 186
# (100557, 32)
# False    100557
# dtype: int64
# 187
# (8945, 32)
# False    8945
# dtype: int64
# 188
# (145942, 32)
# False    145941
# True          1
# dtype: int64
# 189
# (109882, 32)
# False    109879
# True          3
# dtype: int64
# 190
# (3009, 32)
# False    2997
# True       12
# dtype: int64
# 191
# (5000, 32)
# False    5000
# dtype: int64
# 192
# (601, 32)
# False    601
# dtype: int64
# 193
# (113, 32)
# False    113
# dtype: int64
# 194
# (7383, 32)
# False    7383
# dtype: int64
# 195
# (5153, 32)
# False    5153
# dtype: int64
# 196
# (328, 32)
# False    328
# dtype: int64
# 197
# (1315, 32)
# False    1315
# dtype: int64
# 198
# (40, 32)
# False    40
# dtype: int64
# 199
# (236, 32)
# False    236
# dtype: int64
# 200
# (12441, 32)
# False    12440
# True         1
# dtype: int64
# (1898973, 34)

# %% [markdown]
# grouped是按columns分组（数据结构特殊，不是DataFramen！）

# %% [markdown]
# grouped.size() 是series数据结构，index是组，值是每组计数

# %% [markdown]
# .get_group()返回的是每组明细，groupby是对Dataframe则返回的是Dataframe

# %% [markdown]
# 按index[0] 、1、2…… 把文件分到不同组，得到不同分组好的文件路径group_0、group_1……

# %%
# 示例，分组以后，指定第一组第201个文件

grouped = df_group.groupby('Columns') # 注意Column是col_name的元组数据结构值，groupby不支持列表结构的值
df_series = grouped.size()
print(len(df_series.index))
group_0 = grouped.get_group(df_series.index[0]) # 与第一组标题行columns格式一致的分一组
print(group_0.loc[200])
# Out:
# 6
# Path       E:\7.3徐州网赌\20200626经侦来的数据原件总\（304号）光大银行交易明细信息.csv
# Columns    (交易卡号\t, 交易账号\t, 查询反馈结果原因\t, 交易户名\t, 交易证件号码\t,...
# Name: 200, dtype: object

# %%
import pandas as pd

df_group = pd.DataFrame(columns = ['Path','Columns','False','True'])
type1 = '.xls'
type2 = '.csv'
for i in range(len(file_list)):
#     print(i)
    if type1 in file_list[i]:
        df = pd.read_excel(file_list[i], encoding = "gbk")
        col_name = df.columns
        bool_S = df.duplicated().value_counts()
        if len(bool_S)==1:
            df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name),'False':bool_S[0],'True':0}
        elif len(bool_S)==2:
            df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name),'False':bool_S[0],'True':bool_S[1]}

    elif type2 in file_list[i]:
        df = pd.read_csv(file_list[i], engine = "python")
        col_name = df.columns
        bool_S = df.duplicated().value_counts()
        if len(bool_S)==1:
            df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name),'False':bool_S[0],'True':0}
        elif len(bool_S)==2:
            df_group.loc[i] = {'Path':file_list[i],'Columns':tuple(col_name),'False':bool_S[0],'True':bool_S[1]}

grouped = df_group.groupby('Columns')
print(grouped.size())
# Out:
# Columns
# (交易卡号\t, 交易账号\t, 查询反馈结果原因\t, 交易户名\t, 交易证件号码\t, 交易时间\t, 交易金额\t, 交易余额\t, 收付标志\t, 交易对手账卡号\t, 现金标志\t, 对手户名\t, 对手身份证号\t, 对手开户银行\t, 摘要说明\t, 交易币种\t, 交易网点名称\t, 交易场所\t, 交易发生地\t, 交易是否成功\t, 传票号\t, IP地址\t, MAC地址\t, 对手交易余额\t, 交易流水号\t, 渠道\t, 日志号\t, 凭证种类\t, 凭证号\t, 交易柜员号\t, 备注\t, 交易类型\t)                                                                                                                 203
# (客户名称\t, 证照类型\t, 证照号码\t, 单位地址\t, 单位电话\t, 工作单位\t, 邮箱地址\t, 代办人姓名\t, 代办人证件类型\t, 代办人证件号码\t, 国税纳税号\t, 地税纳税号\t, 法人代表\t, 法人代表证件类型\t, 法人代表证件号码\t, 出生日期\t, 户籍地址\t, 客户工商执照号码\t)                                                                                                                                                                                                                              7
# (开户名称\t, 证照类型\t, 证照号码\t, 住宅地址\t, 住宅电话\t)                                                                                                                                                                                                                                                                                                                                                           3
# (开户名称\t, 证照类型\t, 证照号码\t, 联系电话\t)                                                                                                                                                                                                                                                                                                                                                                 142
# (账号\t, 冻结措施类型\t, 冻结措施类型\t.1, 冻结金额\t, 冻结机关\t, 冻结开始日期\t, 冻结截止日期\t, 措施序号\t, 备注\t)                                                                                                                                                                                                                                                                                                                     6
# (账户开户名称\t, 开户人证件号码\t, 交易卡号\t, 交易账号\t, 账号开户时间\t, 账户余额\t, 可用余额\t, 币种\t, 开户网点代码\t, 开户网点\t, 账户状态\t, 炒汇标志名称\t, 销户日期\t, 账户类型\t, 开户联系方式\t, 通信地址\t, 联系电话\t, 代理人\t, 代理人电话\t, 备注\t, 开户省份\t, 开户城市\t, 账号开户银行\t, 客户代码\t, 法人代表\t, 客户工商执照号码\t, 法人代表证件号码\t, 住宅地址\t, 邮政编码\t, 代办人证件号码\t, 邮箱地址\t, 关联资金账户\t, 地税纳税号\t, 单位电话\t, 代办人证件类型\t, 住宅电话\t, 法人代表证件类型\t, 国税纳税号\t, 单位地址\t, 工作单位\t, 销户网点\t, 最后交易时间\t, 账户销户银行\t)     22
# dtype: int64

# %% [markdown]
# 组0是银行交易流水，组5是账户开户信息

# %%
groupname_list = list(grouped.size().index)
print(len(groupname_list))
group_流水 = grouped.get_group(groupname_list[0])
group_流水['文件序号I'] = group_0.index
group_流水.to_excel("E:\\7.3徐州网赌\\流水文件目录.xlsx",index = None)
group_账户 = grouped.get_group(groupname_list[5])
group_账户['文件序号I'] = group_5.index
group_账户.to_excel("E:\\7.3徐州网赌\\账户文件目录.xlsx",index = None)
print('Done!')
# Out:
# 6
# Done!
# D:\Users\ThinkPad\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Users\ThinkPad\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
all_data = pd.DataFrame()
all_account = pd.DataFrame()

for i in range(len(file_list)):
    if file_list[i] in list(group_流水['Path']):
        print(i)
        if type1 in file_list[i]:
            df = pd.read_excel(file_list[i], encoding = "gbk")
            col_name = df.columns.tolist()
            df['path'] = file_list[i]
            df['编号'] = df.index
            data_1 = df.drop_duplicates(subset = col_name,keep = 'last')
            all_data = all_data.append(data_1)
        elif type2 in file_list[i]:
            df = pd.read_csv(file_list[i], engine = "python")
            col_name = df.columns.tolist()
            df['path'] = file_list[i]
            df['编号'] = df.index
            data_1 = df.drop_duplicates(subset = col_name,keep = 'last')
            all_data = all_data.append(data_1)
    elif file_list[i] in list(group_账户['Path']):
        df_account = pd.read_csv(file_list[i], engine = "python")
        df_account['path'] = file_list[i]
        all_account = all_account.append(df_account)
print(all_data.shape)
print(all_account.shape)
# Out:
# 0
# False    4571
# dtype: int64
# 1
# False    2085
# dtype: int64
# 2
# False    253
# dtype: int64
# 4
# False    17414
# True      8354
# dtype: int64
# 5
# False    251
# dtype: int64
# 7
# False    23
# dtype: int64
# 8
# False    609
# dtype: int64
# 10
# False    735
# dtype: int64
# 11
# False    1471
# dtype: int64
# 12
# False    1755
# dtype: int64
# 13
# False    136
# dtype: int64
# 14
# False    1599
# dtype: int64
# 15
# False    8866
# dtype: int64
# 16
# False    5126
# dtype: int64
# 17
# False    17879
# dtype: int64
# 18
# False    502
# dtype: int64
# 19
# False    12525
# dtype: int64
# 20
# False    13029
# dtype: int64
# 21
# False    1941
# dtype: int64
# 22
# False    40976
# dtype: int64
# 23
# False    2564
# dtype: int64
# 24
# False    15590
# dtype: int64
# 25
# False    14282
# dtype: int64
# 26
# False    9229
# dtype: int64
# 28
# False    2015
# dtype: int64
# 29
# False    2607
# dtype: int64
# 30
# False    2849
# True        8
# dtype: int64
# 31
# False    6187
# True        2
# dtype: int64
# 32
# False    404
# dtype: int64
# 33
# False    1320
# dtype: int64
# 36
# False    3161
# dtype: int64
# 38
# False    2709
# dtype: int64
# 39
# False    11326
# dtype: int64
# 40
# False    15
# dtype: int64
# 41
# False    17357
# True      6675
# dtype: int64
# 45
# False    2865
# dtype: int64
# 47
# False    468
# dtype: int64
# 48
# False    668
# dtype: int64
# 49
# False    6676
# dtype: int64
# 57
# False    1405
# dtype: int64
# 59
# False    3491
# dtype: int64
# 60
# False    1387
# dtype: int64
# 61
# False    1590
# dtype: int64
# 62
# False    10125
# dtype: int64
# 70
# False    1000
# dtype: int64
# 72
# False    1000
# dtype: int64
# 75
# False    218
# dtype: int64
# 77
# False    9296
# dtype: int64
# 78
# False    662
# dtype: int64
# 79
# False    2254
# dtype: int64
# 80
# False    3367
# dtype: int64
# 81
# False    5118
# dtype: int64
# 85
# False    7611
# dtype: int64
# 86
# False    942
# dtype: int64
# 89
# False    751
# dtype: int64
# 91
# False    1268
# dtype: int64
# 92
# False    1702
# dtype: int64
# 94
# False    4020
# dtype: int64
# 96
# False    1100
# dtype: int64
# 98
# False    1100
# dtype: int64
# 99
# False    930
# dtype: int64
# 100
# False    128
# dtype: int64
# 104
# False    7993
# dtype: int64
# 105
# False    6564
# dtype: int64
# 107
# False    22520
# dtype: int64
# 109
# False    2564
# dtype: int64
# 110
# False    22520
# dtype: int64
# 111
# False    7993
# dtype: int64
# 116
# False    2187
# dtype: int64
# 118
# False    2406
# dtype: int64
# 120
# False    1197
# dtype: int64
# 121
# False    9152
# dtype: int64
# 124
# False    23459
# dtype: int64
# 125
# False    15026
# dtype: int64
# 126
# False    4698
# dtype: int64
# 127
# False    6725
# dtype: int64
# 129
# False    278
# dtype: int64
# 130
# False    1342
# dtype: int64
# 132
# False    1106
# dtype: int64
# 134
# False    1218
# dtype: int64
# 136
# False    190
# dtype: int64
# 137
# False    792
# dtype: int64
# 138
# False    210
# dtype: int64
# 139
# False    159
# dtype: int64
# 140
# False    2603
# dtype: int64
# 143
# False    995
# dtype: int64
# 144
# False    223
# dtype: int64
# 146
# False    4996
# dtype: int64
# 147
# False    9295
# dtype: int64
# 151
# False    463
# dtype: int64
# 153
# False    190
# dtype: int64
# 154
# False    1958
# dtype: int64
# 155
# False    5622
# dtype: int64
# 157
# False    2546
# dtype: int64
# 159
# False    1248
# dtype: int64
# 161
# False    63
# dtype: int64
# 162
# False    153
# dtype: int64
# 163
# False    110437
# True          4
# dtype: int64
# 166
# False    23192
# True     13923
# dtype: int64
# 167
# False    95691
# dtype: int64
# 168
# False    65534
# True         1
# dtype: int64
# 171
# True     3620
# False    3620
# dtype: int64
# 173
# False    6825
# dtype: int64
# 176
# False    450
# dtype: int64
# 178
# False    103
# dtype: int64
# 179
# False    13390
# dtype: int64
# 182
# False    546
# dtype: int64
# 184
# False    2264
# dtype: int64
# 185
# False    2615
# dtype: int64
# 187
# False    2581
# dtype: int64
# 190
# False    4079
# dtype: int64
# 191
# False    2035
# dtype: int64
# 194
# False    85
# dtype: int64
# 196
# False    2604
# dtype: int64
# 198
# False    996
# dtype: int64
# 200
# False    763
# dtype: int64
# 202
# False    2657
# dtype: int64
# 204
# False    595
# dtype: int64
# 205
# False    2160
# dtype: int64
# 207
# False    7191
# dtype: int64
# 209
# False    2479
# dtype: int64
# 211
# False    2479
# dtype: int64
# 214
# False    1000
# dtype: int64
# 217
# False    1061
# dtype: int64
# 219
# False    1701
# dtype: int64
# 220
# False    4100
# dtype: int64
# 222
# False    11753
# dtype: int64
# 224
# False    148074
# dtype: int64
# 227
# False    2901
# dtype: int64
# 228
# False    1094
# dtype: int64
# 231
# False    797
# dtype: int64
# 233
# False    1349
# dtype: int64
# 234
# False    5994
# True        6
# dtype: int64
# 237
# False    3412
# dtype: int64
# 238
# False    12323
# dtype: int64
# 240
# False    326
# dtype: int64
# 241
# False    10
# dtype: int64
# 243
# False    2623
# dtype: int64
# 245
# False    4537
# dtype: int64
# 248
# False    1590
# dtype: int64
# 251
# False    372
# dtype: int64
# 253
# False    211
# dtype: int64
# 255
# False    148
# dtype: int64
# 256
# False    724
# dtype: int64
# 259
# False    37
# dtype: int64
# 261
# False    1849
# dtype: int64
# 262
# False    1980
# dtype: int64
# 265
# False    216
# dtype: int64
# 267
# False    1377
# dtype: int64
# 268
# False    3782
# dtype: int64
# 270
# False    175
# dtype: int64
# 274
# False    4243
# dtype: int64
# 277
# False    358
# dtype: int64
# 278
# False    5403
# dtype: int64
# 281
# False    2851
# dtype: int64
# 283
# False    25078
# True      5614
# dtype: int64
# 287
# False    18919
# dtype: int64
# 289
# False    2232
# dtype: int64
# 291
# False    144
# dtype: int64
# 292
# False    37152
# True      1569
# dtype: int64
# 295
# False    1289
# dtype: int64
# 297
# False    41477
# True      1213
# dtype: int64
# 301
# False    199999
# True          1
# dtype: int64
# 302
# False    23263
# dtype: int64
# 305
# False    11503
# dtype: int64
# 308
# False    1642
# True     1086
# dtype: int64
# 310
# False    3840
# dtype: int64
# 312
# False    2296
# dtype: int64
# 315
# False    1000
# dtype: int64
# 317
# False    3006
# dtype: int64
# 319
# False    1781
# dtype: int64
# 320
# False    421
# dtype: int64
# 323
# False    1256
# dtype: int64
# 324
# False    33
# dtype: int64
# 327
# False    521
# dtype: int64
# 328
# False    123
# dtype: int64
# 331
# False    214
# dtype: int64
# 333
# False    197
# dtype: int64
# 336
# False    89
# dtype: int64
# 337
# False    2427
# dtype: int64
# 340
# False    62
# dtype: int64
# 341
# False    219
# dtype: int64
# 344
# False    34551
# dtype: int64
# 345
# False    5979
# dtype: int64
# 348
# False    23934
# dtype: int64
# 349
# False    816
# dtype: int64
# 350
# False    1
# dtype: int64
# 351
# False    6187
# True       19
# dtype: int64
# 353
# False    100557
# dtype: int64
# 355
# False    8945
# dtype: int64
# 356
# False    145941
# True          1
# dtype: int64
# 358
# False    109879
# True          3
# dtype: int64
# 360
# False    2997
# True       12
# dtype: int64
# 362
# False    5000
# dtype: int64
# 364
# False    601
# dtype: int64
# 366
# False    113
# dtype: int64
# 368
# False    7383
# dtype: int64
# 372
# False    5153
# dtype: int64
# 374
# False    328
# dtype: int64
# 376
# False    1315
# dtype: int64
# 377
# False    40
# dtype: int64
# 379
# False    236
# dtype: int64
# 382
# False    12440
# True         1
# dtype: int64
# (1901478, 34)
# (97, 44)

# %%
all_data.to_csv("E:\\7.3徐州网赌\\流水汇总.csv",index = None)
all_account.to_csv("E:\\7.3徐州网赌\\账户汇总.csv",index = None)
print('Done!')
# Out:
# Done!

# %%
# # 示例 重复True，不重复False的series数组
# df = pd.read_csv(file_list[382], engine = "python")
# bool_S = df.duplicated().value_counts()
# print(bool_S.index)
# print(bool_S[:].tolist())
# print(bool_S[1])
# print(len(bool_S))
# Out:
# Index([False, True], dtype='object')
# [12440, 1]
# 1
# 2

# %%
if 原始受害人出账，匹配对应收款人进账【时间戳A】，锁定该笔进帐：df_收款方一级.index[i],
df_收款方一级出账中，【时间戳A】之后（按时间sort_values），取时间最接近的匹配单笔DataFrame_after_A_出.index.min()
    #一进一出对应转移
    if  ABS(DataFrame_after_A_出.index.min() - 锁定进账) / 锁定进账 < 5% 
        锁定一级转移单笔
     #多笔汇集再转移
    else if 判断 DataFrame_after_A_出.index.min() > 锁定进账，锁定DataFrame_after_A_出.index.min()【时间戳B】，
             逆推 【时间戳B】之前，df_收款方一级除已锁定【时间戳A】以外的其他收入进账，取时间最接近的DataFrame_before_B_进.index.max()
                if DataFrame_before_B.index.max() / 锁定进账 > 5% & \
                    ABS(DataFrame_after_A_出.index.min() - 锁定进账- DataFrame_before_B_进.index.max() ) / 锁定进账 < 5% 
                    逆向锁定其他收入进帐单笔
                else if DataFrame_after_A_出.index.min() > 锁定进账+ DataFrame_before_B_进.index.max()
                    递归追加收入（

# %%
递归 def 递归追加收入（k）:
    差异比例 = ABS(已计支出 - 已计收入) / 已计收入
        if  差异比例< 5% or 追加后差异比例>差异比例
            print结束；
        else
            追加收入，判断收支
            最近一笔收入 = 已计收入最早时间之前的未计收入中 时间最接近已计收入最早时间的一笔
            已计收入 = 已计收入 + 最近一笔收入
            已计收入最早时间 = min()
            未计收入 = 未计收入 - 最近一笔收入
            追加后差异比例 = ABS(已计支出 - 已计收入) / 已计收入
            递归追加收入（k+1）

# %%
def create_table_sampletb():
    """如果该表不存在, 创建该表"""
    sql = (
        "Create Table If Not Exists sampletb( "
        "PassengerId int Primary key, "
        "Survived int(1), "
        "Pclass int(1), "
        "Name varchar(100), "
        "Sex varchar(10), "
        "Age int(3), "
        "SibSp int(1), "
        "Parch int(1), "
        "Ticket varchar(20), "
        "Fare float, "
        "Cabin varchar(100), "
        "Embarked varchar(10))")
    try:
        conn =  mysql.connector.connect(**mysql_config_sampledb)
        cursor = conn.cursor()
        cursor.execute(sql)
        conn.commit()
    finally:
        conn.close()
        
create_table_sampletb()


select_sampletb = "SELECT * FROM sampletb LIMIT 100"  # 查询数据
select_sampletb_columns = "SHOW columns FROM sampletb"  # 查看表列名

def select_from_sampletb(config, sql):
    """查询语句, 输入数据库的链接信息(字典)以及查询语句.
    打印查询条数, 并返回查询的结果.
    """
    try:
        conn = mysql.connector.connect(**config)
        cursor = conn.cursor()
        cursor.execute(sql)
        result = cursor.fetchall()
    finally:
        conn.close()
    return result

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6109fbc5bfe8> in create_table_sampletb()
#      17     try:
# ---> 18         conn =  mysql.connector.connect(**mysql_config_sampledb)
#      19         cursor = conn.cursor()
#
# NameError: name 'mysql' is not defined
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-6109fbc5bfe8> in <module>
#      23         conn.close()
#      24
# ---> 25 create_table_sampletb()
#      26
#      27
#
# <ipython-input-1-6109fbc5bfe8> in create_table_sampletb()
#      21         conn.commit()
#      22     finally:
# ---> 23         conn.close()
#      24
#      25 create_table_sampletb()
#
# UnboundLocalError: local variable 'conn' referenced before assignment

# %%
import MySQLdb
import pandas as pd
conn = MySQLdb.connect(host='127.0.0.1',user='root',password='123456',db = '2.28test',port=3306,charset='utf8')
cur = conn.cursor() # cursor游标

# cur.execute('select* from table_name') #Execute 将字符串内容当做命令来执行 用来直接执行原生SQL语句
# cur.commit()    # 数据表内容有更新，必须使用到该语句
# rows = cur.fetchall() #fetchall 一次性获取所有数据
# data = pd.DataFrame.from_records(list(rows)) #convert tuple to list to DataFrame
# #data = pd.DataFrame(rows)
# data.to_csv('device.csv',index = False)


import pandas.io.sql as sql
df = sql.read_sql('select * from sheet1',con = conn)
print(df)

conn.close()
# Out:
#        案件ID            数据所属案件          客户名称              客户证件号码  \
# 0      None  外管联合研判线索-青岛-启粤贸易  启粤贸易(深圳)有限公司                None
