# %%
# 20220209_自定义
size_调单人员 = 514
pagesize = 50
page_i = int(size_调单人员 / pagesize)+1

import os
output_path = 'C:\\Users\\zqy\\Desktop\\长城2号\\'
if not os.path.exists(output_path):
    os.mkdir(output_path)
os.chdir(output_path )

import requests
import json
url = 'http://172.30.6.4/ruleResultTest/queryComparedResult'
headers = {'Host': '172.30.6.4',
'Connection': 'keep-alive',
'Content-Length': '75',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
'Content-Type': 'application/json;charset=UTF-8',
'Accept': '*/*',
'Origin': 'http://172.30.6.4',
'Referer': 'http://172.30.6.4/modelTool',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Cookie': 'SHIROJSESSIONID=8b2ce82f-b2bf-4ac6-ba2d-a83513c60621'                                        # Cookie
    }
for i in range(page_i):
    body = {"taskId":"8f87fb0c_2894_453d_aaec_af62655b497f","pageNum":i+1,"pageSize":pagesize}         # taskId
    response = requests.post(url, data = json.dumps(body), headers = headers)
#     print(response.text)
    print(str(i+1)+'Done')

    f2 = open(str(i+1)+'父任务.json', 'w', encoding="utf-8")
    f2.write(response.text)
    f2.close()
    
bankcard_size= 0


import requests
import json
url = 'http://172.30.6.4/ruleResultTest/queryRuleByHitModelCard'
for i in range(page_i):
    with open(str(i+1)+'父任务.json','r', encoding='utf-8')as fp:
        rows = json.load(fp)
    for j in range(len(rows.get('result').get('result'))):
        bankcard_size = bankcard_size + len(rows.get('result').get('result')[j].get('bankList'))       
        for k in range(len(rows.get('result').get('result')[j].get('bankList'))):
#             # 指定限制客户编号
#             set_指定客户编号 = [
# '000190000103399426',
# '001150000092910336',
# '999150000068269223'
# ]
#             if rows.get('result').get('result')[j].get('customerNo') not in set_指定客户编号:
#                 continue
#             #
            
            body = {"taskId":rows.get('result').get('result')[j].get('bankList')[k].get('taskId'),
                    "runId":rows.get('result').get('result')[j].get('bankList')[k].get('runId'),
                    "cardNo":rows.get('result').get('result')[j].get('bankList')[k].get('bankcard')
                   }
            headers = {'Host': '172.30.6.4',
'Connection': 'keep-alive',
'Content-Length': '127',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
'Content-Type': 'application/json;charset=UTF-8',
'Accept': '*/*',
'Origin': 'http://172.30.6.4',
'Referer': 'http://172.30.6.4/modelTool',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Cookie': 'SHIROJSESSIONID=8b2ce82f-b2bf-4ac6-ba2d-a83513c60621'
            }
            response = requests.post(url, data = json.dumps(body), headers = headers)
#             print(response.text)
            f2 = open(str(rows.get('result').get('result')[j].get('bankList')[k].get('bankcard'))+'.json', 'w', encoding="utf-8")
            f2.write(response.text)
            f2.close()
            print(bankcard_size )
        print(j,end = '-')
    print(i,end = '-')
    
import pandas as pd
df_命中汇总 = pd.DataFrame()
bankcard_size= 0
if not os.path.exists(output_path + 'ruleResult'):
    os.mkdir(output_path + 'ruleResult')
os.chdir(output_path)


url = 'http://172.30.6.4/ruleResultTest/test'


for i in range(page_i):
    with open(str(i+1)+'父任务.json','r', encoding='utf-8')as fp:
        rows = json.load(fp)
    for j in range(len(rows.get('result').get('result'))):

#         # 指定限制客户编号
#         if rows.get('result').get('result')[j].get('customerNo') not in set_指定客户编号:
#             continue
#         #
     
        bankcard_size = bankcard_size + len(rows.get('result').get('result')[j].get('bankList'))   
        for k in range(len(rows.get('result').get('result')[j].get('bankList'))):
            with open(str(rows.get('result').get('result')[j].get('bankList')[k].get('bankcard'))+'.json','r', encoding='utf-8') as fpf:
                json_dict = json.load(fpf)
            for p in range(len(json_dict.get('result').get('result') )):
                # 指定限制模型
# or json_dict.get('result').get('result')[p].get('modelId') not in [
# '46257bb4-bb80-4c7b-a90a-399ea7b8d072',
# '66ef113b-7249-40fc-b611-5fd93d8d3055',
# 'bb43b55b-7983-4913-808d-9193c69cda5e']
#                 if json_dict.get('result').get('result')[p].get('proportion')=='0' :    # 限制爬取命中分数不为0的模型
#                     continue
                #
            
                params = {  
'commonId': '',
'modelId': json_dict.get('result').get('result')[p].get('modelId'),
'cardNo': json_dict.get('result').get('result')[p].get('bankcard'),
'taskId': json_dict.get('result').get('result')[p].get('taskId'),
'runId': json_dict.get('result').get('result')[p].get('runId'),
                }   
                headers = {'Host': '172.30.6.4',
'Connection': 'keep-alive',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
'Accept': '*/*',
'Referer': 'http://172.30.6.4/ruleResult?taskId=543f263b_8633_44b5_b134_98b27e52ab93&runId=6339a2bd-fe0c-4423-863a-24a65d3a196c&modelId=35c663e7-bdfd-4128-b2f6-3d9f6be5c23c&cardNo=6217001250014261345',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Cookie': 'SHIROJSESSIONID=8b2ce82f-b2bf-4ac6-ba2d-a83513c60621'
                }
                response = requests.get(url ,params = params, headers = headers)
#                 print(response.text)
                text = json.loads(response.text)
    
                ###
                if text.get('result').get('suspiciousDescription')==None:
                    continue
                rule_size= 0
                df = pd.DataFrame(columns = ['卡号','ruleName','hit','finaRuleResult','模型'])
                for x in range(len( text.get('result').get('suspiciousDescription') )):
                    for y in range(len( text.get('result').get('suspiciousDescription')[x].get('ruleList') )):
                        rule_size_start = rule_size
#                         rule_size = rule_size + len(text.get('result').get('suspiciousDescription')[x].get('ruleList')) 
                        n = rule_size_start + y
                        df.loc[n] = { 
                                '卡号':str(json_dict.get('result').get('result')[p].get('bankcard')),
                                'ruleName':text.get('result').get('suspiciousDescription')[x].get('ruleList')[y].get('ruleName'),
                                'hit':text.get('result').get('suspiciousDescription')[x].get('ruleList')[y].get('hit'),
                                'finaRuleResult':text.get('result').get('suspiciousDescription')[x].get('ruleList')[y].get('finalRuleResult'),
                                '模型':str(json_dict.get('result').get('result')[p].get('modelName'))
                                     }
#                         print('第'+str(y),end = '-')
                    rule_size = rule_size + len(text.get('result').get('suspiciousDescription')[x].get('ruleList')) 
#                     print('组'+str(x),end = ' / ')
                df_命中汇总 = df_命中汇总.append(df)
                ###
    
                f2 = open('ruleResult\\'+ str(json_dict.get('result').get('result')[p].get('bankcard'))+str(json_dict.get('result').get('result')[p].get('modelName'))+'.json', 'w', encoding="utf-8")
                f2.write(response.text)
                f2.close()
                print('模型'+str(p),end = ' ')
#             print('银行卡'+str(bankcard_size) )
        print(j)                                            # 爬取人数进度，提示第i个50人中第j个人
#     print(i)                                              # 提示进度到第i个50人

###
df_命中汇总.to_csv('C:\\Users\\zqy\\Desktop\\长城2号全部详情-20220209_自定义任务.xlsx',index = None)
df_hit = df_命中汇总[df_命中汇总['hit']=='1']
df_hit.to_excel('C:\\Users\\zqy\\Desktop\\长城2号命中详情-20220209_自定义任务.xlsx',index = None)
print('Done!')
###
# Out:
# 模型0 0
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型1 模型2 模型3 模型4 8
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 9
# 模型0 模型1 模型2 模型3 10
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 12
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 13
# 模型0 14
# 模型0 15
# 模型0 模型1 16
# 模型0 模型1 模型2 模型3 17
# 模型0 模型1 模型2 模型3 18
# 模型0 19
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 模型4 模型6 模型7 22
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 模型4 模型5 模型6 23
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 24
# 模型0 模型1 模型2 模型3 25
# 模型0 模型1 模型2 模型3 模型4 模型5 26
# 模型0 模型1 模型2 模型3 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 31
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 32
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 33
# 模型0 模型1 模型2 模型3 34
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型0 模型1 模型2 模型3 模型4 模型5 模型6 37
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 38
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型0 模型1 41
# 模型0 模型1 模型2 模型3 42
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 43
# 模型0 44
# 模型0 模型1 模型2 模型3 45
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 模型22 模型23 模型24 0
# 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型0 模型1 模型2 2
# 模型0 模型0 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 模型4 9
# 模型0 模型1 模型2 模型3 模型4 模型5 10
# 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 12
# 模型0 模型1 模型2 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型2 模型3 15
# 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 模型4 模型5 17
# 模型0 模型1 模型2 模型3 模型4 18
# 模型0 模型1 模型2 模型3 模型4 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 22
# 模型0 模型1 模型2 模型3 23
# 模型0 模型1 模型2 模型3 模型4 模型5 24
# 模型0 模型1 模型2 模型3 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 27
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 28
# 模型0 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 31
# 模型0 模型1 模型2 模型3 32
# 模型0 模型1 模型2 模型3 33
# 模型0 模型1 模型2 模型3 34
# 模型0 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 模型3 37
# 模型0 模型1 模型2 模型3 38
# 模型0 模型1 模型2 模型3 39
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 模型4 模型5 41
# 模型0 模型1 模型2 模型3 42
# 模型0 模型1 模型2 模型3 43
# 模型0 模型1 模型2 44
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 模型4 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 10
# 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 12
# 模型0 模型1 模型2 模型3 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 15
# 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 19
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 22
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 23
# 模型0 模型1 模型2 模型3 24
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 29
# 模型0 30
# 模型0 模型1 模型2 模型3 31
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 32
# 模型0 模型1 模型2 模型3 模型0 模型1 33
# 模型0 模型1 模型2 模型3 模型4 模型5 34
# 模型0 模型1 模型2 模型3 模型4 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 37
# 模型0 模型0 38
# 模型0 模型1 模型2 模型3 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 41
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 42
# 模型0 模型1 模型2 模型3 43
# 模型0 模型1 模型2 44
# 模型0 模型1 模型2 模型3 45
# 模型0 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型2 模型3 模型4 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 10
# 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 12
# 模型0 13
# 模型0 模型1 模型2 14
# 模型0 模型1 模型2 模型3 15
# 模型0 模型1 模型2 模型3 模型4 16
# 模型0 模型1 模型2 模型3 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 21
# 模型0 模型1 模型2 模型3 22
# 模型0 模型1 模型2 模型3 模型4 模型5 23
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 24
# 模型0 模型1 模型2 模型3 模型4 模型5 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 模型3 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 模型4 模型5 31
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 32
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 模型1 模型2 模型3 模型4 模型5 模型6 33
# 模型0 模型1 模型2 模型3 模型4 模型5 34
# 模型0 模型1 模型2 模型3 35
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 36
# 模型0 模型1 模型2 37
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 38
# 模型0 模型1 模型2 模型3 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 模型4 模型5 41
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 42
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型0 模型1 模型2 模型3 43
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 44
# 模型0 模型1 模型2 模型3 模型4 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 模型4 模型5 0
# 模型0 模型1 模型2 模型3 模型4 1
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 2
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 3
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 4
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 8
# 模型0 9
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 10
# 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型0 模型1 模型2 模型3 12
# 模型0 模型1 模型2 模型3 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型2 模型3 15
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 模型4 模型5 22
# 模型0 模型1 模型2 模型3 23
# 模型0 模型1 模型2 模型3 24
# 模型0 模型1 模型2 模型3 25
# 模型0 26
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 27
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 28
# 模型0 模型1 模型2 模型3 29
# 模型0 30
# 模型0 模型1 模型2 模型3 模型4 模型0 模型1 模型2 模型3 31
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 32
# 模型0 模型1 模型2 模型3 33
# 模型0 模型1 模型2 模型3 34
# 模型0 模型1 模型2 模型3 模型4 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 模型3 模型4 37
# 模型0 模型1 模型2 模型3 38
# 模型0 模型1 模型2 模型3 模型4 模型5 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 41
# 模型0 模型1 模型2 模型3 42
# 模型0 模型1 模型2 模型3 43
# 模型0 44
# 模型0 模型1 模型2 模型3 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 47
# 模型0 模型1 模型2 模型3 模型4 模型5 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 7
# 模型0 模型1 模型2 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 10
# 模型0 模型1 模型2 模型3 模型4 11
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 模型4 12
# 模型0 模型1 模型2 模型3 13
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 14
# 模型0 模型1 模型2 模型3 15
# 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 17
# 模型0 模型1 模型2 18
# 模型0 模型1 模型2 模型3 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 21
# 模型0 22
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 23
# 模型0 模型1 模型2 模型3 模型4 模型0 模型1 模型2 模型3 模型4 模型5 24
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 29
# 模型0 模型1 模型2 模型3 模型4 模型5 30
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 31
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 32
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 33
# 模型0 模型1 模型2 模型3 模型4 34
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型0 模型1 模型2 模型3 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 37
# 模型0 模型1 模型2 模型3 模型4 模型5 38
# 模型0 模型1 模型2 模型3 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 41
# 模型0 42
# 模型0 43
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 44
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 45
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 模型22 模型23 模型0 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 1
# 模型0 模型1 模型2 模型3 模型4 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 6
# 模型0 模型1 模型2 模型3 模型4 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 模型4 9
# 模型0 模型1 模型2 模型3 模型4 10
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 11
# 模型0 模型1 模型2 模型3 12
# 模型0 模型1 模型2 模型3 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型0 模型1 模型2 模型3 15
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 16
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 17
# 模型0 模型1 模型2 18
# 模型0 模型1 模型2 模型3 19
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 20
# 模型0 模型1 模型2 模型3 21
# 模型0 22
# 模型0 模型1 模型2 23
# 模型0 模型1 模型2 模型3 24
# 模型0 模型1 模型2 模型3 25
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 26
# 模型0 模型1 模型2 模型3 27
# 模型0 28
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 31
# 模型0 模型1 模型2 模型3 32
# 模型0 模型1 模型2 模型3 33
# 模型0 模型1 模型2 模型3 34
# 模型0 模型1 模型2 模型3 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 模型3 37
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 38
# 模型0 模型1 模型2 模型3 39
# 模型0 40
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 41
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 42
# 模型0 模型1 模型2 模型3 43
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 44
# 模型0 模型1 模型2 模型3 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 模型4 48
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 49
# 模型0 模型1 模型2 模型3 0
# 模型0 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型0 模型1 3
# 模型0 模型0 4
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型2 模型3 模型0 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 10
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 11
# 模型0 模型1 模型2 12
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 13
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 模型21 模型22 14
# 模型0 15
# 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 模型4 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 模型20 22
# 模型0 模型1 模型2 模型3 模型4 23
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 24
# 模型0 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 27
# 模型0 模型1 模型2 模型3 模型4 模型5 28
# 模型0 模型1 模型2 29
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 30
# 模型0 模型1 模型2 模型3 模型4 模型5 31
# 模型0 32
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 33
# 模型0 34
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 35
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 36
# 模型0 模型1 模型2 模型3 37
# 模型0 模型1 模型2 模型3 38
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 模型18 模型19 41
# 模型0 模型1 模型2 模型3 42
# 模型0 模型1 模型2 模型3 43
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 44
# 模型0 模型1 模型2 模型3 45
# 模型0 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 模型2 模型3 模型0 模型1 4
# 模型0 模型1 模型2 模型3 5
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 9
# 模型0 模型1 模型2 模型3 10
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 11
# 模型0 模型1 模型2 12
# 模型0 模型1 模型2 模型3 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型2 模型3 模型4 15
# 模型0 模型0 模型1 模型2 模型3 16
# 模型0 模型1 模型2 模型3 模型4 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 19
# 模型0 模型1 模型2 模型3 20
# 模型0 模型1 模型2 模型3 模型4 模型5 21
# 模型0 模型1 模型2 模型3 模型4 模型5 22
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 23
# 模型0 模型1 模型2 模型3 24
# 模型0 模型1 模型2 模型3 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 模型4 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 模型3 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 模型4 模型5 31
# 模型0 模型1 模型2 模型3 32
# 模型0 模型1 模型2 模型3 33
# 模型0 模型1 模型2 模型3 模型4 模型5 34
# 模型0 模型1 模型2 模型3 35
# 模型0 模型1 模型2 模型3 模型4 36
# 模型0 模型1 模型2 模型3 37
# 模型0 模型0 模型1 38
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 39
# 模型0 模型1 模型2 模型3 40
# 模型0 模型1 模型2 模型3 41
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 42
# 模型0 模型1 模型2 模型3 模型4 43
# 模型0 模型1 模型2 模型3 44
# 模型0 模型1 模型2 模型3 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 模型4 模型5 48
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型10 模型11 模型12 模型13 模型14 模型15 模型16 模型17 49
# 模型0 模型1 模型2 模型3 模型4 模型5 0
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 模型3 模型4 模型5 5
# 模型0 模型1 模型2 模型3 6
# 模型0 模型1 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型9 模型0 模型1 模型2 模型3 模型4 7
# 模型0 模型1 模型2 模型3 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 10
# 模型0 模型1 模型2 模型3 11
# 模型0 12
# 模型0 模型1 模型2 模型3 模型4 模型5 13
# 模型0 模型1 模型2 模型3 14
# 模型0 模型1 模型2 模型3 模型4 15
# 模型0 模型1 模型2 模型3 16
# 模型0 17
# 模型0 模型1 模型2 模型3 18
# 模型0 模型1 模型2 模型3 19
# 模型0 20
# 模型0 模型1 模型2 模型3 21
# 模型0 模型1 模型2 模型3 22
# 模型0 模型1 模型2 模型3 23
# 模型0 模型1 模型2 模型3 模型4 24
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 25
# 模型0 模型1 模型2 模型3 26
# 模型0 模型1 模型2 模型3 模型4 模型5 27
# 模型0 模型1 模型2 模型3 28
# 模型0 模型1 模型2 29
# 模型0 模型1 模型2 模型3 30
# 模型0 模型1 模型2 模型3 模型4 31
# 模型0 模型1 模型2 模型3 32
# 模型0 模型1 模型2 模型3 模型4 模型5 33
# 模型0 模型1 模型2 模型3 34
# 模型0 模型1 模型2 模型3 35
# 模型0 模型1 模型2 模型3 36
# 模型0 模型1 模型2 模型3 模型4 模型5 37
# 模型0 模型1 模型2 模型3 模型0 模型1 模型2 模型3 38
# 模型0 模型1 模型2 模型3 39
# 模型0 模型1 模型2 模型3 40
# 模型0 41
# 模型0 模型1 模型2 模型3 模型4 模型5 模型0 模型1 42
# 模型0 模型1 模型2 43
# 模型0 模型1 模型2 模型3 44
# 模型0 45
# 模型0 模型1 模型2 模型3 46
# 模型0 模型1 模型2 模型3 47
# 模型0 模型1 模型2 模型3 48
# 模型0 模型1 模型2 模型3 49
# 模型0 模型1 模型2 模型3 0
# 模型0 模型1 模型2 模型3 1
# 模型0 模型1 模型2 模型3 2
# 模型0 模型1 模型2 模型3 3
# 模型0 模型1 模型2 模型3 4
# 模型0 模型1 模型2 模型3 模型4 模型5 5
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 6
# 模型0 模型1 模型2 模型3 7
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 8
# 模型0 模型1 模型2 模型3 9
# 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 模型8 模型0 模型1 模型2 模型3 模型4 模型5 模型6 模型7 10
# 模型0 11
# 模型0 模型1 模型2 模型3 12
# 模型0 模型1 模型2 模型3 13
# Done!

# %%
import os
input_path = 'K:\\DATA\\20211125\\'
output_path = 'K:\\长城2号场景一数据清洗\\'
if not os.path.exists(output_path):
    os.mkdir(output_path)
os.chdir(output_path )


import os
file_list = []
os.chdir(input_path)
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if '$' not in file:
            file_list.append(os.path.join(path_name, file))
print(len(file_list))
print('\n'.join(file_list))

if not os.path.exists(output_path):
    os.mkdir(output_path)

import pandas as pd
df_流水汇总 = pd.DataFrame()
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if '_AML_SSPCS_RPT_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_3号令 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_3号令.columns = ['客户编号','反洗钱报告编号','反洗钱可疑交易笔数','金融机构网点名称','金融机构网点所在地区行政区划代码','反洗钱报告对公对私代码','可疑交易特征描述','反洗钱业务规则名称','反洗钱报告最大交易日期','反洗钱报告最小交易日期','反洗钱报告涉及人民币交易金额','反洗钱报告涉及人民币交易笔数','反洗钱传统渠道人民币交易金额','反洗钱电子银行渠道人民币交易金额','反洗钱新兴电子渠道人民币交易金额','反洗钱其他渠道人民币交易金额','反洗钱传统渠道交易笔数','反洗钱电子银行渠道交易笔数','反洗钱新兴电子渠道交易笔数','反洗钱其他渠道交易笔数','可疑交易措施描述','可疑交易报告报送方向代码','反洗钱可疑行为描述','#报告报送状态代码','报送日期','可疑交易报送标志','#批量导入日期','反洗钱交易主体账户个数','反洗钱中心机构编号','反洗钱中心机构中文名称','#备注二(洗钱类型)','报送次数','接续报告参考标志(0-否 1-是)','非可疑行为描述','可疑交易报告疑点分析说明','可疑交易报告疑点分析及排除理由','反洗钱可疑行为描述2','可疑交易报告疑点分析说明2','风险等级']
            df_3号令.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('3号令Done！')
        elif '_IDV_BASE_IMG_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_对私基本 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_对私基本.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','客户姓名','证件类型','证件号码','性别','出生日期','年龄','民族','职业','职务','最佳联系电话','主地址','工作地址','国家地区代码','单位名称','个人住房贷款客户标志','非保本理财客户标志','保本理财客户标志','电话银行签约标志','短信金融签约标志','网上银行签约标志','手机银行签约标志','客户月均AUM值','单位客户编号','公司名称','四部委规模','客户所属行业','组织机构代码','营业执照号码','注册资本币种','注册资本','注册地址','经营地址','办公地址','员工人数','组织实收资本金额','经营状态代码','组织成立日期','机构经营范围说明','公司联系电话','法定代表人证件类型','法定代表人证件号码','法定代表人','授权代表人证件类型','授权代表人证件号码','授权代表人','业务联系人证件类型','业务联系人证件号码','业务联系人','实际控制人证件类型','实际控制人证件号码','实际控制人','受益所有人证件类型','受益所有人证件号码','受益所有人','风险等级','商户标志']
            df_对私基本.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('对私基本Done！')
        elif '_CORP_BASE_IMG_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_对公基本 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_对公基本.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','客户名称','所属机构','四部委规模','客户所属行业','组织机构代码','营业执照号码','注册资本币种','注册资本','组织实收资本金额','信贷客户标识','联系电话','注册地址','经营地址','办公地址','对公客户类型','员工人数','经营状态代码','组织成立日期','主营业务描述','机构经营范围说明','企业网银签约标识','企业手机银行签约标志','企业网银高级版签约标志','企业手机银行高级版签约标志','企业网银简版签约标志','企业手机银行简版签约标志','法定代表人证件类型','法定代表人证件号码','法定代表人','授权代表人证件类型','授权代表人证件号码','授权代表人','业务联系人证件类型','业务联系人证件号码','业务联系人','实际控制人证件类型','实际控制人证件号码','实际控制人','受益所有人证件类型','受益所有人证件号码','受益所有人','风险等级','商户标志']
            df_对公基本.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('对公基本Done！')
        elif '_IDV_OPN_ACCT_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_对私开户 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_对私开户.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','对公对私标志','账户开户名称','开户证件号码','客户账号','开户日期','存款账户余额','可用余额','币种代码','钞汇代码','开户机构编号','开户机构名称','开户二级分行名称','账户状态代码描述','销户日期','销户机构编号','联系电话','通讯地址','邮政编码','电子邮件地址','营业执照编号','国税登记号','地税登记号','企业法人姓名','企业法人证件类型','企业法人证件号码','授权代理人名称','授权代理人证件类型代码','授权代理人证件号码','最后交易营业日期','账户收付控制状态代码']
            df_对私开户.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('对私开户Done！')
        elif '_CORP_OPN_ACCT_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_对公开户 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_对公开户.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','对公对私标志','账户开户名称','开户证件号码','客户账号','开户日期','存款账户余额','可用余额','币种代码','钞汇代码','开户机构编号','开户机构名称','开户二级分行名称','账户状态代码描述','销户日期','销户机构编号','联系电话','通讯地址','邮政编码','电子邮件地址','营业执照编号','国税登记号','地税登记号','企业法人姓名','企业法人证件类型','企业法人证件号码','授权代理人名称','授权代理人证件类型代码','授权代理人证件号码','最后交易营业日期','账户收付控制状态代码']
            df_对公开户.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('对公开户Done！')
#         elif '_REL_' in file:
#             with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
#                 lines = f.readlines()
#             df = pd.DataFrame(lines)
#             df_关联 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
#             df_关联.columns = ['客户编号','类罪','反洗钱报告编号','场景','客户名称','关联类型','关系类型详细描述','对公对私标志','证件类型','证件号码','关联人名称','关联人客户编号']
#             df_关联.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
#             print('关联Done！')
        elif '_TRAN_' in file:
            with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
                lines = f.readlines()
            df = pd.DataFrame(lines)
            df_流水 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
            df_流水.columns = ['类罪类型','反洗钱报告编号','场景类型','交易ID','客户编号','交易日期','明细来源','业务种类','业务条线','报送业务条线','明细序号','定活存标志','账卡标志','客户账号','客户名称','对公对私标志','客户年龄','国际卡卡币种','币种代码','存款种类','可售产品编号','资金用途代码','客户类型代码','交易时间','交易金额','折人民币金额','折美元金额','借贷标志','收付标志','交易种类','交易方式','汇款种类','交易渠道种类','交易流水号','全局事件跟踪号','交易柜员号','交易代码','交易机构','交易机构名称','交易发生地','交易所在国家地区代码','交易方向','凭证号码','凭证种类','摘要代码','摘要描述','账户性质','账户类型','资金用途','开户机构','开户机构名称','开户机构行政区划','反洗钱机构','反洗钱机构名称','开户日期','销户日期','上次明细交易日','产品种类','交易对手系统账号','交易对手账号修饰符','交易对手账户类型','交易对手账户性质','交易对手对公对私标志','交易对手客户账号','交易对手客户编号','交易对手客户名称','交易对手本外行标识','交易对手证件号码','交易对手证件类型','交易对手证件类型说明','交易对手商户编号','交易对手商户种类','交易对手开户机构','交易对手开户机构行政区划','交易对手定活存标志','交易对手金融机构代码','交易对手金融机构名称','交易对手金融机构行政区划','交易对手金融机构代码网点类型','交易对手国籍地区','终端信息','大额豁免标志','老可疑豁免标志','新可疑豁免标志','代理人姓名','代理人证件类型','代理人证件类型说明','代理人证件号码','代理人电话','代理人国籍地区','是否被代办','是否跨境交易','结算类型现金转账消费','是否跨行交易','是否异地交易','补录机构','账户余额','备注1','备注2']
            df_流水.to_csv(output_path +file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
            print('流水Done！')
            df_流水汇总 = df_流水汇总.append(df_流水)
            
if not os.path.exists(output_path + '拆分'):
    os.mkdir(output_path + '拆分')
df_分编号 = df_流水汇总.groupby(['客户编号'],as_index = False).size()
print(len(df_分编号))
# Out:
# 11
# K:\DATA\20211125\20211125_自定义任务详情.xlsx
# K:\DATA\20211125\P20210257_JS_FXQ_ACCT_ACDN_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_AML_SSPCS_RPT_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_CORP_BASE_IMG_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_CORP_OPN_ACCT_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_COUNT_JDGMT_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_IDV_BASE_IMG_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_IDV_OPN_ACCT_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_JDCL_FRZ_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_REL_20211125_0001.dat
# K:\DATA\20211125\P20210257_JS_FXQ_TRAN_20211125_0001.dat
# 3号令Done！
# 对公基本Done！
# 对公开户Done！
# 对私基本Done！
# 对私开户Done！
# 流水Done！
# 514

# %%
for i in df_分编号.index:
    df_every = df_流水汇总.groupby(['客户编号'],as_index = False).get_group(df_分编号['客户编号'][i]).sort_values(by = ['客户账号','交易日期','交易时间'],ascending=[True,True,True])
    if len(df_every)<655360:
        df_every.to_excel(output_path +'拆分\\'+ str(df_every['客户名称'].iloc[0])+str(df_every['客户编号'].iloc[0])+'.xlsx',index = None)
        print(i,end = ' ')
    else:
        size = df_every.index.size
        limit = 500000
        sheets = int(size / limit)+1

        with pd.ExcelWriter(output_path +'拆分\\'+ str(df_every['客户名称'].iloc[0])+str(df_every['客户编号'].iloc[0])+'.xlsx') as writer:
            for j in range(sheets):
                start = limit * j
                stop = limit * (j+1)
                print(str(i)+'-'+str(j),end = ' ')
                data = df_every.iloc[start:stop].astype(str).replace('nan','')
                data.to_excel(writer, sheet_name='sheet'+str(j),index = False)
print('Done!')
