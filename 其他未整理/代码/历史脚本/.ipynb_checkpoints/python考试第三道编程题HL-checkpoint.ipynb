# %%
import pandas as pd
import re
import os
df = pd.read_excel(r'C:\Users\ThinkPad\Desktop\python考试题目\编程题-第3题\银川建行（原始数据）.xlsx',encoding = 'gbk',dtype = 'object')
df = df.applymap(lambda x: re.sub('nan','',str(x)))

df_证件 = df['Unnamed: 0'][df['Unnamed: 0'].str.contains('根据查询条件')]
df_户名 =df['Unnamed: 0'][df['Unnamed: 0'].str.contains('客户名称:')]

df_开户信息表 = pd.DataFrame(columns = ['客户名称','客户编号','交易账号','交易卡号'])
df_合并 = pd.DataFrame(columns = ['合并'])

for i in df_户名.index:
    for k in df_证件.index:
        if i > k and i< df_证件.reset_index().iloc[len(df_证件.loc[:k])]['index']:
            df_合并.loc[i] = {'合并':df_户名[i] + df_证件[k]}
            print(f_户名[i] + df_证件[k])
            
output_path = 'C:\\Users\\ThinkPad\\Desktop\\'
if not os.path.exists(output_path + './python答案HL'):
    os.mkdir(output_path + './python答案HL')
df_合并.to_excel(output_path + 'python答案HL\\编程题第三题1.xlsx',index = None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-16712628592c> in <module>
#       9
#      10 df_开户信息表 = pd.DataFrame(columns = ['客户名称','客户编号','交易账号','交易卡号'])
# ---> 11 df_合并 = pd.DataFrame(columns = '合并')
#      12
#      13 for i in df_户名.index:
#
# D:\Users\ThinkPad\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# D:\Users\ThinkPad\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     219         from pandas.core.series import Series
#     220
# ...

# %%
df_开户信息表 = pd.DataFrame(columns = ['客户名称','客户编号','交易账号','交易卡号'])
df_合并 = pd.DataFrame(columns = ['合并'])

for i in df_户名.index:
    for k in df_证件.index:
        if len(df_证件.loc[:k])< len(df_证件):
            if i > k and i< df_证件.reset_index().iloc[len(df_证件.loc[:k])]['index']:
                df_合并.loc[i] = {'合并':df_户名[i] + df_证件[k]}
                print(df_户名[i] + df_证件[k])
        elif len(df_证件.loc[:k])== len(df_证件):
            if i > k:
                df_合并.loc[i] = {'合并':df_户名[i] + df_证件[k]}
                print(df_户名[i] + df_证件[k])
print(df_合并)
# Out:
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4478029980130064177，卡号:4478029980130064177，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4478029980130075165，卡号:4478029980130075165，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4478029980130189628，卡号:6236684470000784845，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4478029980130189636，卡号:6236684470000784852，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4479079980130314280，卡号:6227004479070221440，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4479089980130013195，卡号:4479089980130013195，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 客户名称:李晓菲，客户编号:121190000103710592，客户账号:4479129980100822072，卡号:4367424480420822075，币别:人民币元，钞汇标志:钞根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# ...

# %%
df_合并['合并'].str.split(' ', 1,expand = True)
# Out:
#                                                        0  \
# 7      客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 641    客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 696    客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 1212   客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 1877   客户名称:李晓菲，客户编号:121190000103710592，客户账号:44790799...
# ...                                                  ...
# 23150  客户名称:刘振环，客户编号:417190000103450291，客户账号:44715299...
# 23171  客户名称:刘慧慧，客户编号:211180000148951410，客户账号:44701399...
# 23288  客户名称:韩雨，客户编号:542190000103485920，客户账号:447447998...
# 24170  客户名称:马伟银，客户编号:142150000109450269，客户账号:64055020...
# 24223  客户名称:王吉祥，客户编号:237140000072033984，客户账号:44735099...
#
#                                         1
# 7      【 证件号码:640202197901180526 】查询结果如下：
# 641    【 证件号码:640202197901180526 】查询结果如下：
# 696    【 证件号码:640202197901180526 】查询结果如下：
# 1212   【 证件号码:640202197901180526 】查询结果如下：
# 1877   【 证件号码:640202197901180526 】查询结果如下：
# ...

# %%
import re
pattern = re.compile(r'[\x80-\xff]')
str = u'脚本之家jb51'
print(pattern.search(str))
# Out:
# None

# %%
import re
pattern = r'[\u4e00-\u9fa5]+?:'
regex = re.compile(pattern,flags=re.IGNORECASE)
df_合并['合并'].str.findall(pattern,,flags = re.IGNORECASE)
# Out:
#   File "<ipython-input-112-026693336f92>", line 3
#     df_合并['合并'].str.findall(pattern,,flags=re.IGNORECASE)
#                                     ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                                               Unnamed: 0 Unnamed: 1  \
# 0                                           个人活期明细信息-新一代
# 1                                   数据截止2019-06-24系统结账时间
# 2      1、本查询结果以“数据截止日期”为准，之后可能会发生变化。2、本查询结果中“个人信用卡”专指...
# 3
# 4
# ...                                                  ...        ...
# 24226                                         2017-01-26   11:45:14
# 24227                                         2017-01-26   16:13:01
# 24228                                         2017-01-27   17:42:14
# 24229                                         2017-01-28   13:00:36
# 24230                                         2017-01-28   13:00:36
#
#       Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0
# 1
# 2
# 3
# 4
# ...          ...                  ...        ...        ...        ...
# 24226          2  6217004470020807793       转帐支取          5          0
# 24227          3  6217004470020807793         消费       0.01          0
# ...

# %%
df_证件 = df['Unnamed: 0'][df['Unnamed: 0'].str.contains('根据查询条件')]
df_证件
# Out:
# 5        根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 4545     根据查询条件 【 证件号码:640202197111150517 】查询结果如下：
# 5356     根据查询条件 【 证件号码:659001197609281832 】查询结果如下：
# 5548     根据查询条件 【 证件号码:642221196712122454 】查询结果如下：
# 5711     根据查询条件 【 证件号码:642101197110153329 】查询结果如下：
# 5722     根据查询条件 【 证件号码:642101198203140337 】查询结果如下：
# 5727     根据查询条件 【 证件号码:642101198611011729 】查询结果如下：
# 5995     根据查询条件 【 证件号码:642223198012183629 】查询结果如下：
# 6116     根据查询条件 【 证件号码:642223198610173658 】查询结果如下：
# 7382     根据查询条件 【 证件号码:642223197708193636 】查询结果如下：
# 7428     根据查询条件 【 证件号码:640202194810240526 】查询结果如下：
# 7440     根据查询条件 【 证件号码:642101195912200060 】查询结果如下：
# 7489     根据查询条件 【 证件号码:640102198010231827 】查询结果如下：
# 8084     根据查询条件 【 证件号码:640121199607270013 】查询结果如下：
# 9077     根据查询条件 【 证件号码:640102197112091242 】查询结果如下：
# 9728     根据查询条件 【 证件号码:210902197804084530 】查询结果如下：
# 10559    根据查询条件 【 证件号码:640202198408100523 】查询结果如下：
# 11184    根据查询条件 【 证件号码:640203197205110117 】查询结果如下：
# ...

# %%
df_户名 =df['Unnamed: 0'][df['Unnamed: 0'].str.contains('客户名称:')]
df_户名
# Out:
# 7        客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 641      客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 696      客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 1212     客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 1877     客户名称:李晓菲，客户编号:121190000103710592，客户账号:44790799...
#                                ...
# 23150    客户名称:刘振环，客户编号:417190000103450291，客户账号:44715299...
# 23171    客户名称:刘慧慧，客户编号:211180000148951410，客户账号:44701399...
# 23288    客户名称:韩雨，客户编号:542190000103485920，客户账号:447447998...
# 24170    客户名称:马伟银，客户编号:142150000109450269，客户账号:64055020...
# 24223    客户名称:王吉祥，客户编号:237140000072033984，客户账号:44735099...
# Name: Unnamed: 0, Length: 88, dtype: object

# %%
df
# Out:
# 0                                             个人活期明细信息-新一代
# 1                                     数据截止2019-06-24系统结账时间
# 2        1、本查询结果以“数据截止日期”为准，之后可能会发生变化。2、本查询结果中“个人信用卡”专指...
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 24226                                           2017-01-26
# 24227                                           2017-01-26
# 24228                                           2017-01-27
# 24229                                           2017-01-28
# 24230                                           2017-01-28
# Name: Unnamed: 0, Length: 24231, dtype: object

# %%
df.head(10)
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                       个人活期明细信息-新一代
# 1                               数据截止2019-06-24系统结账时间
# 2  1、本查询结果以“数据截止日期”为准，之后可能会发生变化。2、本查询结果中“个人信用卡”专指...
# 3
# 4
# 5          根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 6                                       个人活期明细信息-新一代
# 7  客户名称:李晓菲，客户编号:121190000103710592，客户账号:44780299...
# 8                                               交易日期       交易时间        明细号
# 9                                         2013-04-01   09:50:07          1
#
#             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8                 交易卡号         摘要      借方发生额      贷方发生额       账户余额      交易机构号
# 9  4478029980130064177       转帐存入          0     480000     480000  640001300
#
#    Unnamed: 9          Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# ...

# %%
k = 6116
print(len(df_证件.loc[:k]))
df_证件.loc[:k]
# Out:
# 9
# 5       根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 4545    根据查询条件 【 证件号码:640202197111150517 】查询结果如下：
# 5356    根据查询条件 【 证件号码:659001197609281832 】查询结果如下：
# 5548    根据查询条件 【 证件号码:642221196712122454 】查询结果如下：
# 5711    根据查询条件 【 证件号码:642101197110153329 】查询结果如下：
# 5722    根据查询条件 【 证件号码:642101198203140337 】查询结果如下：
# 5727    根据查询条件 【 证件号码:642101198611011729 】查询结果如下：
# 5995    根据查询条件 【 证件号码:642223198012183629 】查询结果如下：
# 6116    根据查询条件 【 证件号码:642223198610173658 】查询结果如下：
# Name: Unnamed: 0, dtype: object

# %%
df_证件.reset_index().iloc[len(df_证件.loc[:k])]['index']
# Out:
# 7382

# %%
df_证件.index[]
# Out:
#     index                                 Unnamed: 0
# 0       5  根据查询条件 【 证件号码:640202197901180526 】查询结果如下：
# 1    4545  根据查询条件 【 证件号码:640202197111150517 】查询结果如下：
# 2    5356  根据查询条件 【 证件号码:659001197609281832 】查询结果如下：
# 3    5548  根据查询条件 【 证件号码:642221196712122454 】查询结果如下：
# 4    5711  根据查询条件 【 证件号码:642101197110153329 】查询结果如下：
# 5    5722  根据查询条件 【 证件号码:642101198203140337 】查询结果如下：
# 6    5727  根据查询条件 【 证件号码:642101198611011729 】查询结果如下：
# 7    5995  根据查询条件 【 证件号码:642223198012183629 】查询结果如下：
# 8    6116  根据查询条件 【 证件号码:642223198610173658 】查询结果如下：
# 9    7382  根据查询条件 【 证件号码:642223197708193636 】查询结果如下：
# 10   7428  根据查询条件 【 证件号码:640202194810240526 】查询结果如下：
# 11   7440  根据查询条件 【 证件号码:642101195912200060 】查询结果如下：
# 12   7489  根据查询条件 【 证件号码:640102198010231827 】查询结果如下：
# 13   8084  根据查询条件 【 证件号码:640121199607270013 】查询结果如下：
# 14   9077  根据查询条件 【 证件号码:640102197112091242 】查询结果如下：
# 15   9728  根据查询条件 【 证件号码:210902197804084530 】查询结果如下：
# 16  10559  根据查询条件 【 证件号码:640202198408100523 】查询结果如下：
# ...

# %%
df_户名.index
# Out:
# Int64Index([    7,   641,   696,  1212,  1877,  1885,  1889,  1899,  1917,
#              1924,  4547,  4588,  4669,  4774,  4836,  5358,  5384,  5466,
#              5550,  5713,  5729,  5855,  5870,  5997,  6107,  6118,  7230,
#              7287,  7384,  7391,  7430,  7442,  7485,  7491,  7543,  8075,
#              8079,  8086,  9079,  9320,  9730,  9949, 10561, 10662, 11186,
#             11196, 11225, 11229, 15354, 17615, 17722, 17730, 17892, 18400,
#             18612, 18962, 19062, 19076, 19097, 19119, 19155, 19159, 19231,
#             19495, 19506, 19978, 19996, 20020, 20046, 20191, 20402, 20754,
#             20762, 20771, 21210, 22007, 22611, 22652, 22659, 22841, 22922,
#             23075, 23101, 23150, 23171, 23288, 24170, 24223],
#            dtype='int64')

# %%
    for k in Index_list证件:
        if i > k and i< k+1:
            df_证件[i] + df_证件[k]

# %%
df_户名.index
# Out:
# Int64Index([    7,   641,   696,  1212,  1877,  1885,  1889,  1899,  1917,
#              1924,  4547,  4588,  4669,  4774,  4836,  5358,  5384,  5466,
#              5550,  5713,  5729,  5855,  5870,  5997,  6107,  6118,  7230,
#              7287,  7384,  7391,  7430,  7442,  7485,  7491,  7543,  8075,
#              8079,  8086,  9079,  9320,  9730,  9949, 10561, 10662, 11186,
#             11196, 11225, 11229, 15354, 17615, 17722, 17730, 17892, 18400,
#             18612, 18962, 19062, 19076, 19097, 19119, 19155, 19159, 19231,
#             19495, 19506, 19978, 19996, 20020, 20046, 20191, 20402, 20754,
#             20762, 20771, 21210, 22007, 22611, 22652, 22659, 22841, 22922,
#             23075, 23101, 23150, 23171, 23288, 24170, 24223],
#            dtype='int64')

# %%
len(df_证件.loc[:k])
# Out:
# 39

# %%
k
# Out:
# 24221

# %%
len(df_证件)
# Out:
# 39

# %%
df_证件.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-2d956c64bb0f> in <module>
# ----> 1 df_证件.shape()
#
# TypeError: 'tuple' object is not callable
