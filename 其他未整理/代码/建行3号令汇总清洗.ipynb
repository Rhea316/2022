# %%
import pandas as pd
input_path = 'D:\\对公基本dat汇总\\'

import os
str1 = ''
file_list = []
os.chdir(input_path)
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if '$' not in file:
            file_list.append(os.path.join(path_name, file))
print(len(file_list))
print('\n'.join(file_list))


output_path = 'K:\\对公基本数据清洗\\'

for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
            lines = f.readlines()

        df = pd.DataFrame(lines)
        df_对公基本 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
        if df_对公基本.shape[1]==45:
            df_对公基本.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','客户名称','所属机构','四部委规模','客户所属行业','组织机构代码','营业执照号码','注册资本币种','注册资本','组织实收资本金额','信贷客户标识','联系电话','注册地址','经营地址','办公地址','对公客户类型','员工人数','经营状态代码','组织成立日期','主营业务描述','机构经营范围说明','企业网银签约标识','企业手机银行签约标志','企业网银高级版签约标志','企业手机银行高级版签约标志','企业网银简版签约标志','企业手机银行简版签约标志','法定代表人证件类型','法定代表人证件号码','法定代表人','授权代表人证件类型','授权代表人证件号码','授权代表人','业务联系人证件类型','业务联系人证件号码','业务联系人','实际控制人证件类型','实际控制人证件号码','实际控制人','受益所有人证件类型','受益所有人证件号码','受益所有人']
        elif df_对公基本.shape[1]==47:
            df_对公基本.columns = ['客户编号','类罪','反洗钱报告编号','场景类型','客户名称','所属机构','四部委规模','客户所属行业','组织机构代码','营业执照号码','注册资本币种','注册资本','组织实收资本金额','信贷客户标识','联系电话','注册地址','经营地址','办公地址','对公客户类型','员工人数','经营状态代码','组织成立日期','主营业务描述','机构经营范围说明','企业网银签约标识','企业手机银行签约标志','企业网银高级版签约标志','企业手机银行高级版签约标志','企业网银简版签约标志','企业手机银行简版签约标志','法定代表人证件类型','法定代表人证件号码','法定代表人','授权代表人证件类型','授权代表人证件号码','授权代表人','业务联系人证件类型','业务联系人证件号码','业务联系人','实际控制人证件类型','实际控制人证件号码','实际控制人','受益所有人证件类型','受益所有人证件号码','受益所有人','风险等级','商户标志']
        df_对公基本.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
        print(str(file.split('.')[0])+'对公基本Done！')
# Out:
# 18
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210407_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210410_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210425_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210504_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210428_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210712_0001_three.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210812_0001_one.dat
# D:\对公基本dat汇总\P202102XX_JS_FXQ_CORP_BASE_IMG_20210812_0001_three.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210806_0001_one.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210416_0001.dat
# D:\对公基本dat汇总\P202102HL_JS_FXQ_CORP_BASE_IMG_20210419_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210422_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210507_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210510_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210513_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210516_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210519_0001.dat
# D:\对公基本dat汇总\P20210257_JS_FXQ_CORP_BASE_IMG_20210522_0001.dat
# P20210257_JS_FXQ_CORP_BASE_IMG_20210407_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210410_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210425_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210504_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210428_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210712_0001_three对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210812_0001_one对公基本Done！
# P202102XX_JS_FXQ_CORP_BASE_IMG_20210812_0001_three对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210806_0001_one对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210416_0001对公基本Done！
# P202102HL_JS_FXQ_CORP_BASE_IMG_20210419_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210422_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210507_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210510_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210513_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210516_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210519_0001对公基本Done！
# P20210257_JS_FXQ_CORP_BASE_IMG_20210522_0001对公基本Done！

# %%
    
    
import pandas as pd
input_path = 'D:\\3号令dat汇总\\'

import os
str1 = ''
file_list = []
os.chdir(input_path)
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if '$' not in file:
            file_list.append(os.path.join(path_name, file))
print(len(file_list))
print('\n'.join(file_list))


output_path = 'D:\\3号令数据清洗\\'

for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
            lines = f.readlines()

        df = pd.DataFrame(lines)
        df_3号令 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
        df_3号令.columns = ['客户编号','反洗钱报告编号','反洗钱可疑交易笔数','金融机构网点名称','金融机构网点所在地区行政区划代码','反洗钱报告对公对私代码','可疑交易特征描述','反洗钱业务规则名称','反洗钱报告最大交易日期','反洗钱报告最小交易日期','反洗钱报告涉及人民币交易金额','反洗钱报告涉及人民币交易笔数','反洗钱传统渠道人民币交易金额','反洗钱电子银行渠道人民币交易金额','反洗钱新兴电子渠道人民币交易金额','反洗钱其他渠道人民币交易金额','反洗钱传统渠道交易笔数','反洗钱电子银行渠道交易笔数','反洗钱新兴电子渠道交易笔数','反洗钱其他渠道交易笔数','可疑交易措施描述','可疑交易报告报送方向代码','反洗钱可疑行为描述','#报告报送状态代码','报送日期','可疑交易报送标志','#批量导入日期','反洗钱交易主体账户个数','反洗钱中心机构编号','反洗钱中心机构中文名称','#备注二(洗钱类型)','报送次数','接续报告参考标志(0-否 1-是)','非可疑行为描述','可疑交易报告疑点分析说明','可疑交易报告疑点分析及排除理由','反洗钱可疑行为描述2','可疑交易报告疑点分析说明2','风险等级']
        df_3号令.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
        print(str(file.split('.')[0])+'3号令Done！')
# Out:
# 11
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210518_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210622_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210624_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210627_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210628_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210708_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210407_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210410_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210425_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210428_0001.dat
# D:\3号令dat汇总\P20210257_JS_FXQ_AML_SSPCS_RPT_20210504_0001.dat
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210518_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210622_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210624_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210627_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210628_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210708_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210407_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210410_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210425_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210428_00013号令Done！
# P20210257_JS_FXQ_AML_SSPCS_RPT_20210504_00013号令Done！

# %%
    
    
import pandas as pd
input_path = 'D:\\账户事故dat汇总\\'

import os
str1 = ''
file_list = []
os.chdir(input_path)
for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        if '$' not in file:
            file_list.append(os.path.join(path_name, file))
print(len(file_list))
print('\n'.join(file_list))


output_path = 'K:\\账户事故数据清洗\\'

for path_name, dir, files_name in os.walk(os.getcwd()):
    for file in files_name:
        with open(os.path.join(path_name, file), encoding = 'utf-8') as f:
            lines = f.readlines()

        df = pd.DataFrame(lines)
        df_账户事故 = df[0].str.split('\|\@\|',expand = True).iloc[:,:-1]
        df_账户事故.columns = ['客户编号','类罪','反洗钱报告编号','场景','卡号','日期','时间','事故序号','交易机构','交易渠道','经办','授权','修改前信息','修改后信息','备注','事故名称']
        df_账户事故.to_csv(output_path + file.split('.')[0]+'.csv', encoding = 'utf-8',index = None)
        print(str(file.split('.')[0])+'账户事故Done！')
# Out:
# 16
# D:\账户事故dat汇总\P202102HL_JS_FXQ_ACCT_ACDN_20210419_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210407_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210425_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210709_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210708_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210410_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210416_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210422_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210428_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210504_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210507_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210510_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210513_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210516_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210519_0001.dat
# D:\账户事故dat汇总\P20210257_JS_FXQ_ACCT_ACDN_20210522_0001.dat
# P202102HL_JS_FXQ_ACCT_ACDN_20210419_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210407_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210425_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210709_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210708_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210410_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210416_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210422_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210428_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210504_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210507_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210510_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210513_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210516_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210519_0001账户事故Done！
# P20210257_JS_FXQ_ACCT_ACDN_20210522_0001账户事故Done！

# %%
df_账户事故
# Out:
#                    客户编号    类罪               反洗钱报告编号   场景                   卡号  \
# 0    007190000103629819        32020210516S00000698  场景二  6217001260016884077
# 1    022190000103539842              20210522-02-XZ  场景二  6217001280000730946
# 2    022190000103539842              20210522-02-XZ  场景二  6217001280600016456
# 3    026190000103455813              20210522-02-XZ  场景二  6217001250009980974
# 4    027190000103414443        32020210515S00003649  场景二  6227001272611058584
# ..                  ...   ...                   ...  ...                  ...
# 389  981190000103413787              20210522-02-XZ  场景二  1301579980110174724
# 390  991110000216119580  1201  32020210514S00001544  场景二  6217001290011706991
# 391  996190000103391156              20210522-02-XZ  场景二  6227001333070138935
# 392  998100000029847764        32020210515S00002102  场景二  6217001370037621794
# 393  998100000124254033              20210522-02-XZ  场景二  6217001320011991150
#
#              日期        时间 事故序号       交易机构             交易渠道        经办  \
# 0    2021-03-26   1:38:54    3  320628436         99999999  00000001
# 1    2021-03-31   9:52:41    2  320651236  002932065123600  79799032
# 2    2021-03-31   9:55:32    3  320651236  002932065123600  79799032
# 3    2021-06-13   1:26:41    1  320714700         99999999  00000001
# 4    2021-02-25   5:15:29    3  320647236         99999999
# ..          ...       ...  ...        ...              ...       ...
# 389  2021-03-31  12:37:26    3  320755336     0109320C1302  320C1302
# 390  2021-05-26   1:47:19    2  320723536         99999999  00000001
# 391  2021-01-13   1:30:23    1  320747736         99999999  00000001
# 392  2021-03-26   1:39:31    3  320597342         99999999  00000001
# 393  2021-05-28  16:41:12    1  320737638  002932073763800  17501729
#
#            授权 修改前信息 修改后信息    备注  事故名称
# 0                                0596
# 1    25286289                    0190
# 2    63153026                    0190
# 3                                0312
# 4                                0016
# ..        ...   ...   ...   ...   ...
# 389              正常  永久挂失        0500
# 390                              0587
# 391                              0517
# 392                              0596
# 393  37591811    正常  只收不付  可疑交易  0184
#
# [394 rows x 16 columns]
