# %%
# 20211013_自定义
size_调单人员 = 617
pagesize = 50
page_i = int(size_调单人员 / pagesize)+1

import os
output_path = 'C:\\Users\\zqy\\Desktop\\机器学习\\'
if not os.path.exists(output_path):
    os.mkdir(output_path)
os.chdir(output_path )

import requests
import json
url = 'http://172.30.6.4/ruleResultTest/queryHitModelCard'
headers = {'Host': '172.30.6.4',
'Connection': 'keep-alive',
'Content-Length': '76',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
'Content-Type': 'application/json;charset=UTF-8',
'Accept': '*/*',
'Origin': 'http://172.30.6.4',
'Referer': 'http://172.30.6.4/modelTuning',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Cookie': 'SHIROJSESSIONID=a35dbf08-8c5c-4392-94cc-849cd8d02207'                                        # Cookie
    }
for i in range(page_i):
    body = {"modelId":"5838f99a-e191-4651-b7c9-9b2d58868564","pageNum":i+1,"pageSize":pagesize}          # taskId
    response = requests.post(url, data = json.dumps(body), headers = headers)
    print(response.text)
    print(str(i+1)+'Done')

    f2 = open(str(i+1)+'机器学习.json', 'w', encoding="utf-8")
    f2.write(response.text)
    f2.close()
# Out:
# {"code":200,"message":"success","result":{"result":[{"id":null,"modelId":"5838f99a-e191-4651-b7c9-9b2d58868564","taskId":"0351619b_608a_4a69_9aa6_1bebeac1f597","proportion":"100","bankcard":"32001727136052518527","customerNo":"613890000008604115","customerName":null,"cardType":null,"cardNumber":null,"clueType":0,"reportTime":null,"taskType":null,"runId":"dc6d3040-debb-46fb-81d5-48043c89040b","isCommon":null,"modelName":null,"isSystem":null,"parentTaskId":null,"createBy":null,"updateBy":null,"createTime":null,"updateTime":null,"rsTaskResultModelId":null,"hitCrime":null},{"id":null,"modelId":"5838f99a-e191-4651-b7c9-9b2d58868564","taskId":"c37cb040_9733_4f6c_885f_305d1aa4a118","proportion":"100","bankcard":"32050164723600004874","customerNo":"491890000000006977","customerName":null,"cardType":null,"cardNumber":null,"clueType":0,"reportTime":null,"taskType":null,"runId":"4c3e32d5-4e41-43d8-ad25-c4f999642d3f","isCommon":null,"modelName":null,"isSystem":null,"parentTaskId":null,"createBy"
# ...
