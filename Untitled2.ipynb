# %%
import re
import camelot
import pandas as pd
table1 = camelot.read_pdf(r'C:\Users\zqy\Desktop\OA\美团打车电子发票1(19).pdf',pages = '1-end',flavor='stream')    # 得到一个camelot.core.Table对象
df = pd.DataFrame()
for k in range(len(table1)):
    print(k,end = ' ')
    df = df.append(table1[k].df)    # table对象的df属性，得到一个pandas.core.frame.DataFrame对象
    print(df.shape ,end = ' ')
    
df
# Out:
# 0 (26, 4)
#                                                  0            1    2  \
# 0
# 1                                                   上海增值税电子普通发票
# 2
# 3
# 4
# 5                              499099821381\n机器编号：
# 6                             智器云南京信息科技有限公司\n名\n称：
# 7                                                购                 密
# 8                      9132010430251885X8\n纳税人识别号：
# 9
# 10                                               买                 码
# 11                                        地 址、电 话：
# 12                                               方                 区
# 13                                         开户行及账号：
# 14                     货物或应税劳务、服务名称\n规格型号\n单位\n数 量               单 价
# 15                               *运输服务*客运服务费\n无\n次            1
# 16                                            合\n计
# 17                               贰拾圆陆角陆分\n价税合计（大写）
# 18                               上海路团科技有限公司\n名\n称：
# 19                                               销
# ...
