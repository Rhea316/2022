# %%
import reportlab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-643c40455ab4> in <module>()
# ----> 1 import reportlab
#
# ModuleNotFoundError: No module named 'reportlab'

# %%
import pandas as pd
import re
import os
input_path = 'C:\\Users\\zqy\\Desktop\\素材\\'
os.chdir(input_path)
df = pd.read_csv(input_path +'data\\part-00000-be8233b7-5d30-434f-aaf6-f7857e3cdc8c-c000.csv',dtype = object)
df = df.applymap(lambda x: re.sub('nan','',str(x)))
df['交易金额'] = df['交易金额'].map(lambda x: float(x))
print(df.dtypes)
print(df)
# Out:
# 交易卡号         object
# 交易账号         object
# 交易户名         object
# 日期时间         object
# 交易方向         object
# 交易金额        float64
# 交易余额         object
# 对方卡号         object
# 对方账号         object
# 对方户名         object
# 交易摘要         object
# 备注           object
# IP地址         object
# MAC地址        object
# 本方开户银行       object
# 对方开户银行       object
# 本方证件号        object
# 对方证件号        object
# 交易流水号        object
# 交易网点         object
# 交易地点         object
# 交易渠道         object
# 币种           object
# 交易是否成功       object
# 查询反馈结果原因     object
# dtype: object
#                        交易卡号                 交易账号 交易户名                 日期时间  \
# 0       4367427200062495726  4367427200062495726  唐海燕  2018-01-29 09:05:05
# 1       4367427200062495726  4367427200062495726  唐海燕  2018-02-09 00:26:01
# 2       4367427200062495726  4367427200062495726  唐海燕  2018-02-12 00:33:25
# 3       4367427200062495726  4367427200062495726  唐海燕  2018-02-24 00:09:37
# ...
